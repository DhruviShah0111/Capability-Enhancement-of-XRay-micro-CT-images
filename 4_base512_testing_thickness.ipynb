# %% [markdown]
# #Imports and path setup

# %%
# imports
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import os
#from google.colab.patches import cv_imshow
import cv2
import imgaug 
import imgaug as ia
import imgaug.augmenters as iaa
from sklearn.model_selection import train_test_split
import random
import shutil
from statistics import mean

# %%
# define paths
bmp_path = '/kaggle/input'
op_path = '/kaggle/working'
circle_path = bmp_path + '/circles_new'
bamboo_path = bmp_path + '/bamboo'
image_path = bmp_path + '/minorproject'
train_image_path = image_path + '/train_images_latest'
true_image_path = image_path + '/true_images_new'
raw_masks_path = f"{bmp_path}/raw_masks_new/"
masks_path = f"{bmp_path}/masks_new/"
test_path=bmp_path + '/testing-datasets/'

# %%
X = np.array(list(map(lambda a : image_path + '/' + a, os.listdir(image_path))))
y = np.array(list(map(lambda a : true_image_path + '/' + a, os.listdir(true_image_path))))

# %%
print(X.shape)
# Out:
# (2,)

# %%
print(y.shape)
# Out:
# (2525,)

# %% [markdown]
# ## Image generator

# %%
# function for normalization
def normalize(input_image):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  # input_mask = tf.cast(input_mask, tf.float32) / 255.0
  return input_image

# %%
# generate image dataset
img_dim = 256
batch_sz = 1
image_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2,shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
mask_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2,shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
#print(image_datagen.shape)

train_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode=,
        batch_size = batch_sz,
        seed=42,
        subset='training')
    
train_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        batch_size = batch_sz,
        seed=42,
        subset='training')

val_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')
    
val_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')


train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 2020 images belonging to 1 classes.
# Found 2020 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.

# %%
training_samples_size = train_image_generator.samples
val_samples_size = val_image_generator.samples
print(training_samples_size)
print(val_samples_size)
# Out:
# 2020
# 505

# %% [markdown]
# ##U-Net

# %%
# batch/buffer sizes for NN
BATCH_SIZE = 8
BUFFER_SIZE = 1000
# train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# validation_batches = test_dataset.take(3000).batch(BATCH_SIZE)
# test_batches = test_dataset.skip(3000).take(669).batch(BATCH_SIZE)

# %%
# custom convolution
def conv_block(input, num_filters):
  # First Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(input)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  # Second Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(x)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  
  return x

# %%
# custom encoder
def encoder_block(input, num_filters):
  x = conv_block(input, num_filters)
  p = layers.MaxPool2D(2)(x)

  return x, p

# %%
# custom decoder
def decoder_block(input, skip_features, num_filters):
  x = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')(input)
  x = layers.Concatenate()([skip_features, x])
  x = layers.Dropout(0.3)(x)
  x = conv_block(x, num_filters)

  return x

# %%
# function to build unet
def build_unet_model(input_shape):
  inputs = layers.Input(shape=input_shape)

  # Encoders
  #s1, p1 = encoder_block(inputs,8)
  #s1, p1= encoder_block(inputs,16)
  s1, p1= encoder_block(inputs,32)
  s2, p2= encoder_block(p1,64)
  s3, p3= encoder_block(p2,128)
  s4, p4= encoder_block(p3, 256)
  #s6, p6= encoder_block(p5, 512)
  # s5, p6 = encoder_block(p4, 1024)

  # Base
  b = conv_block(p4, 512)

  # Decoders
  # d = decoder_block(b, s5, 1024)
  #d1 = decoder_block(b, s6, 512)
  d1 = decoder_block(b, s4, 256)
  d2 = decoder_block(d1,s3,128)
  d3 = decoder_block(d2,s2,64)
  d4 = decoder_block(d3, s1, 32)
  #d6 = decoder_block(d5, s1, 16)
  #d6 = decoder_block(d5, s1, 8)
  

  # Output
  outputs = layers.Conv2D(3, 3, padding='same', activation='relu')(d4)

  # UNet model 
  unet_model = keras.Model(inputs, outputs, name='U-Net')

  return unet_model

# %%
#SSIM metrics
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)

def ape(y_true, y_pred):
  return tf.keras.losses.MeanAbsolutePercentageError(y_true, y_pred)

# %%
# build model
unet_model = build_unet_model((img_dim, img_dim, 3))

# %%
# unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
#                   loss="MSE",
#                   metrics=[ssim, tf.keras.metrics.MeanAbsolutePercentageError()])
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss="MSE",
                  metrics=[ssim])

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 32  0           ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['activation[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 256, 256, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['activation_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 128, 128, 64  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['activation_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 128, 128, 64  0           ['conv2d_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['activation_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['conv2d_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['activation_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_4[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['activation_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 256)  0           ['conv2d_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['activation_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['batch_normalization_6[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 256)  0           ['conv2d_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['activation_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 512)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 512)  2048       ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 512)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 512)  2048       ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  1179904    ['batch_normalization_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['dropout[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 256)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 256)  1024       ['activation_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 256)  0           ['conv2d_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 256)  1024       ['activation_11[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  295040     ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['dropout_1[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 128)  0           ['conv2d_12[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 128)  512        ['activation_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_12[0][0]']
#
#  activation_13 (Activation)     (None, 64, 64, 128)  0           ['conv2d_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 128)  512        ['activation_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  73792      ['batch_normalization_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['batch_normalization_3[0][0]',
#                                 8)                                'conv2d_transpose_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 128, 128, 12  0           ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['dropout_2[0][0]']
#                                 )
#
#  activation_14 (Activation)     (None, 128, 128, 64  0           ['conv2d_14[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 64  256        ['activation_14[0][0]']
#  ormalization)                  )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_14[0][0]']
#                                 )
#
#  activation_15 (Activation)     (None, 128, 128, 64  0           ['conv2d_15[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 64  256        ['activation_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  18464      ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['batch_normalization_1[0][0]',
#                                 )                                 'conv2d_transpose_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 256, 256, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['dropout_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 256, 256, 32  0           ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['activation_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 256, 256, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 32  128        ['activation_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 3)  867         ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 8,643,107
# Trainable params: 8,637,219
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# save model
model_path = op_path + "/unet4.h5"
checkpoint = keras.callbacks.ModelCheckpoint(model_path,
                             monitor="loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

# earlystop = keras.callbacks.EarlyStopping(monitor = 'loss', 
#                           min_delta = 0, 
#                           patience = 5,
#                           verbose = 1,
#                           restore_best_weights = True)

# %%
history = unet_model.fit(train_generator,
                    steps_per_epoch=training_samples_size//BATCH_SIZE,
                    validation_data=val_generator,
                    validation_steps=val_samples_size//BATCH_SIZE,
                    epochs=100, callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 2023-04-26 03:18:19.872954: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 252/252 [==============================] - ETA: 0s - loss: 0.0316 - ssim: 0.6545
# Epoch 1: loss improved from inf to 0.03160, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 40s 83ms/step - loss: 0.0316 - ssim: 0.6545 - val_loss: 0.3107 - val_ssim: 1.3177e-04
# Epoch 2/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0065 - ssim: 0.8647
# Epoch 2: loss improved from 0.03160 to 0.00647, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 21s 85ms/step - loss: 0.0065 - ssim: 0.8647 - val_loss: 0.0115 - val_ssim: 0.8067
# Epoch 3/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0051 - ssim: 0.8852
# Epoch 3: loss improved from 0.00647 to 0.00508, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 21s 84ms/step - loss: 0.0051 - ssim: 0.8852 - val_loss: 0.0350 - val_ssim: 0.7848
# Epoch 4/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0046 - ssim: 0.8973
# Epoch 4: loss improved from 0.00508 to 0.00462, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 22s 86ms/step - loss: 0.0046 - ssim: 0.8973 - val_loss: 0.0077 - val_ssim: 0.8817
# Epoch 5/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0023 - ssim: 0.9187
# Epoch 5: loss improved from 0.00462 to 0.00228, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 21s 84ms/step - loss: 0.0023 - ssim: 0.9187 - val_loss: 0.0100 - val_ssim: 0.8854
# Epoch 6/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0016 - ssim: 0.9287
# Epoch 6: loss improved from 0.00228 to 0.00164, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 21s 85ms/step - loss: 0.0016 - ssim: 0.9287 - val_loss: 0.0083 - val_ssim: 0.9047
# Epoch 7/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0020 - ssim: 0.9222
# Epoch 7: loss did not improve from 0.00164
# 252/252 [==============================] - 20s 79ms/step - loss: 0.0020 - ssim: 0.9222 - val_loss: 0.0018 - val_ssim: 0.9377
# Epoch 8/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0018 - ssim: 0.9295
# Epoch 8: loss did not improve from 0.00164
# 252/252 [==============================] - 21s 82ms/step - loss: 0.0018 - ssim: 0.9295 - val_loss: 0.0016 - val_ssim: 0.9474
# Epoch 9/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0013 - ssim: 0.9369
# Epoch 9: loss improved from 0.00164 to 0.00133, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0013 - ssim: 0.9369 - val_loss: 0.0105 - val_ssim: 0.9101
# Epoch 10/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0013 - ssim: 0.9393
# Epoch 10: loss improved from 0.00133 to 0.00132, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 17s 68ms/step - loss: 0.0013 - ssim: 0.9393 - val_loss: 0.0158 - val_ssim: 0.8734
# Epoch 11/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0016 - ssim: 0.9344
# Epoch 11: loss did not improve from 0.00132
# 252/252 [==============================] - 18s 73ms/step - loss: 0.0016 - ssim: 0.9344 - val_loss: 0.0020 - val_ssim: 0.9563
# Epoch 12/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0013 - ssim: 0.9404
# Epoch 12: loss improved from 0.00132 to 0.00128, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 77ms/step - loss: 0.0013 - ssim: 0.9404 - val_loss: 0.0024 - val_ssim: 0.9508
# Epoch 13/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9391
# Epoch 13: loss improved from 0.00128 to 0.00124, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0012 - ssim: 0.9391 - val_loss: 0.0493 - val_ssim: 0.7503
# Epoch 14/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0013 - ssim: 0.9324
# Epoch 14: loss did not improve from 0.00124
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0013 - ssim: 0.9323 - val_loss: 0.0290 - val_ssim: 0.8385
# Epoch 15/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0014 - ssim: 0.9288
# Epoch 15: loss did not improve from 0.00124
# 252/252 [==============================] - 18s 72ms/step - loss: 0.0014 - ssim: 0.9288 - val_loss: 0.0026 - val_ssim: 0.9479
# Epoch 16/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9412
# Epoch 16: loss improved from 0.00124 to 0.00111, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 74ms/step - loss: 0.0011 - ssim: 0.9412 - val_loss: 0.0083 - val_ssim: 0.9151
# Epoch 17/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0027 - ssim: 0.9276
# Epoch 17: loss did not improve from 0.00111
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0027 - ssim: 0.9276 - val_loss: 0.1804 - val_ssim: 0.3708
# Epoch 18/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0032 - ssim: 0.9055
# Epoch 18: loss did not improve from 0.00111
# 252/252 [==============================] - 18s 72ms/step - loss: 0.0032 - ssim: 0.9055 - val_loss: 0.0842 - val_ssim: 0.6115
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0021 - ssim: 0.9144
# Epoch 19: loss did not improve from 0.00111
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0021 - ssim: 0.9144 - val_loss: 0.0026 - val_ssim: 0.9261
# Epoch 20/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0014 - ssim: 0.9228
# Epoch 20: loss did not improve from 0.00111
# 252/252 [==============================] - 18s 72ms/step - loss: 0.0014 - ssim: 0.9228 - val_loss: 0.0022 - val_ssim: 0.9244
# Epoch 21/100
# 252/252 [==============================] - ETA: 0s - loss: 9.8531e-04 - ssim: 0.9289
# Epoch 21: loss improved from 0.00111 to 0.00099, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 17s 66ms/step - loss: 9.8531e-04 - ssim: 0.9289 - val_loss: 0.0038 - val_ssim: 0.9276
# Epoch 22/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9368
# Epoch 22: loss did not improve from 0.00099
# 252/252 [==============================] - 26s 102ms/step - loss: 0.0011 - ssim: 0.9368 - val_loss: 0.0056 - val_ssim: 0.9348
# Epoch 23/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0010 - ssim: 0.9381
# Epoch 23: loss did not improve from 0.00099
# 252/252 [==============================] - 18s 73ms/step - loss: 0.0010 - ssim: 0.9380 - val_loss: 0.0094 - val_ssim: 0.9141
# Epoch 24/100
# 252/252 [==============================] - ETA: 0s - loss: 8.1591e-04 - ssim: 0.9411
# Epoch 24: loss improved from 0.00099 to 0.00082, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 20s 81ms/step - loss: 8.1591e-04 - ssim: 0.9411 - val_loss: 0.0087 - val_ssim: 0.9219
# Epoch 25/100
# 252/252 [==============================] - ETA: 0s - loss: 8.2633e-04 - ssim: 0.9434
# Epoch 25: loss did not improve from 0.00082
# 252/252 [==============================] - 19s 75ms/step - loss: 8.2633e-04 - ssim: 0.9434 - val_loss: 0.0078 - val_ssim: 0.9245
# Epoch 26/100
# 252/252 [==============================] - ETA: 0s - loss: 8.2247e-04 - ssim: 0.9434
# Epoch 26: loss did not improve from 0.00082
# 252/252 [==============================] - 18s 72ms/step - loss: 8.2247e-04 - ssim: 0.9434 - val_loss: 0.0096 - val_ssim: 0.9178
# Epoch 27/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.5835e-04 - ssim: 0.9462
# Epoch 27: loss improved from 0.00082 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 76ms/step - loss: 7.5844e-04 - ssim: 0.9461 - val_loss: 0.0073 - val_ssim: 0.9275
# Epoch 28/100
# 252/252 [==============================] - ETA: 0s - loss: 7.7761e-04 - ssim: 0.9450
# Epoch 28: loss did not improve from 0.00076
# 252/252 [==============================] - 18s 72ms/step - loss: 7.7761e-04 - ssim: 0.9450 - val_loss: 0.0096 - val_ssim: 0.9172
# Epoch 29/100
# 252/252 [==============================] - ETA: 0s - loss: 8.1000e-04 - ssim: 0.9456
# Epoch 29: loss did not improve from 0.00076
# 252/252 [==============================] - 16s 66ms/step - loss: 8.1000e-04 - ssim: 0.9456 - val_loss: 0.0117 - val_ssim: 0.9069
# Epoch 30/100
# 252/252 [==============================] - ETA: 0s - loss: 7.7062e-04 - ssim: 0.9468
# Epoch 30: loss did not improve from 0.00076
# 252/252 [==============================] - 18s 72ms/step - loss: 7.7062e-04 - ssim: 0.9468 - val_loss: 0.0085 - val_ssim: 0.9183
# Epoch 31/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1751e-04 - ssim: 0.9491
# Epoch 31: loss improved from 0.00076 to 0.00072, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 74ms/step - loss: 7.1751e-04 - ssim: 0.9491 - val_loss: 0.0096 - val_ssim: 0.9222
# Epoch 32/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6136e-04 - ssim: 0.9478
# Epoch 32: loss did not improve from 0.00072
# 252/252 [==============================] - 19s 75ms/step - loss: 7.6136e-04 - ssim: 0.9478 - val_loss: 0.0122 - val_ssim: 0.9117
# Epoch 33/100
# 252/252 [==============================] - ETA: 0s - loss: 7.2231e-04 - ssim: 0.9476
# Epoch 33: loss did not improve from 0.00072
# 252/252 [==============================] - 18s 72ms/step - loss: 7.2231e-04 - ssim: 0.9476 - val_loss: 0.0119 - val_ssim: 0.9127
# Epoch 34/100
# 252/252 [==============================] - ETA: 0s - loss: 7.5639e-04 - ssim: 0.9479
# Epoch 34: loss did not improve from 0.00072
# 252/252 [==============================] - 19s 75ms/step - loss: 7.5639e-04 - ssim: 0.9479 - val_loss: 0.0071 - val_ssim: 0.9318
# Epoch 35/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0294e-04 - ssim: 0.9505
# Epoch 35: loss improved from 0.00072 to 0.00070, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 16s 65ms/step - loss: 7.0294e-04 - ssim: 0.9505 - val_loss: 0.0109 - val_ssim: 0.9219
# Epoch 36/100
# 252/252 [==============================] - ETA: 0s - loss: 7.5201e-04 - ssim: 0.9494
# Epoch 36: loss did not improve from 0.00070
# 252/252 [==============================] - 19s 75ms/step - loss: 7.5201e-04 - ssim: 0.9494 - val_loss: 0.0137 - val_ssim: 0.9150
# Epoch 37/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1960e-04 - ssim: 0.9490
# Epoch 37: loss did not improve from 0.00070
# 252/252 [==============================] - 18s 73ms/step - loss: 7.1960e-04 - ssim: 0.9490 - val_loss: 0.0158 - val_ssim: 0.9099
# Epoch 38/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1430e-04 - ssim: 0.9507
# Epoch 38: loss did not improve from 0.00070
# 252/252 [==============================] - 16s 64ms/step - loss: 7.1430e-04 - ssim: 0.9507 - val_loss: 0.0179 - val_ssim: 0.9119
# Epoch 39/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.8247e-04 - ssim: 0.9508
# Epoch 39: loss did not improve from 0.00070
# 252/252 [==============================] - 19s 76ms/step - loss: 7.8224e-04 - ssim: 0.9508 - val_loss: 0.0017 - val_ssim: 0.9453
# Epoch 40/100
# 252/252 [==============================] - ETA: 0s - loss: 8.2199e-04 - ssim: 0.9462
# Epoch 40: loss did not improve from 0.00070
# 252/252 [==============================] - 16s 63ms/step - loss: 8.2199e-04 - ssim: 0.9462 - val_loss: 0.0016 - val_ssim: 0.9527
# Epoch 41/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.3263e-04 - ssim: 0.9480
# Epoch 41: loss did not improve from 0.00070
# 252/252 [==============================] - 17s 66ms/step - loss: 7.3323e-04 - ssim: 0.9479 - val_loss: 0.0011 - val_ssim: 0.9603
# Epoch 42/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.1160e-04 - ssim: 0.9512
# Epoch 42: loss did not improve from 0.00070
# 252/252 [==============================] - 18s 72ms/step - loss: 7.1125e-04 - ssim: 0.9512 - val_loss: 0.0015 - val_ssim: 0.9562
# Epoch 43/100
# 252/252 [==============================] - ETA: 0s - loss: 7.3262e-04 - ssim: 0.9505
# Epoch 43: loss did not improve from 0.00070
# 252/252 [==============================] - 16s 65ms/step - loss: 7.3262e-04 - ssim: 0.9505 - val_loss: 0.0025 - val_ssim: 0.9525
# Epoch 44/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1815e-04 - ssim: 0.9503
# Epoch 44: loss did not improve from 0.00070
# 252/252 [==============================] - 18s 73ms/step - loss: 7.1815e-04 - ssim: 0.9503 - val_loss: 0.0054 - val_ssim: 0.9495
# Epoch 45/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6859e-04 - ssim: 0.9512
# Epoch 45: loss did not improve from 0.00070
# 252/252 [==============================] - 19s 76ms/step - loss: 7.6859e-04 - ssim: 0.9512 - val_loss: 0.0019 - val_ssim: 0.9568
# Epoch 46/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8818e-04 - ssim: 0.9506
# Epoch 46: loss improved from 0.00070 to 0.00069, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 17s 67ms/step - loss: 6.8818e-04 - ssim: 0.9506 - val_loss: 0.0015 - val_ssim: 0.9570
# Epoch 47/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4125e-04 - ssim: 0.9508
# Epoch 47: loss did not improve from 0.00069
# 252/252 [==============================] - 19s 74ms/step - loss: 7.4125e-04 - ssim: 0.9508 - val_loss: 0.0014 - val_ssim: 0.9567
# Epoch 48/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1771e-04 - ssim: 0.9507
# Epoch 48: loss did not improve from 0.00069
# 252/252 [==============================] - 19s 75ms/step - loss: 7.1771e-04 - ssim: 0.9507 - val_loss: 0.0020 - val_ssim: 0.9560
# Epoch 49/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5740e-04 - ssim: 0.9518
# Epoch 49: loss improved from 0.00069 to 0.00066, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 75ms/step - loss: 6.5740e-04 - ssim: 0.9518 - val_loss: 0.0022 - val_ssim: 0.9570
# Epoch 50/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0476e-04 - ssim: 0.9538
# Epoch 50: loss did not improve from 0.00066
# 252/252 [==============================] - 19s 75ms/step - loss: 7.0476e-04 - ssim: 0.9538 - val_loss: 0.0014 - val_ssim: 0.9615
# Epoch 51/100
# 252/252 [==============================] - ETA: 0s - loss: 7.3086e-04 - ssim: 0.9522
# Epoch 51: loss did not improve from 0.00066
# 252/252 [==============================] - 18s 73ms/step - loss: 7.3086e-04 - ssim: 0.9522 - val_loss: 0.0013 - val_ssim: 0.9616
# Epoch 52/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6787e-04 - ssim: 0.9535
# Epoch 52: loss did not improve from 0.00066
# 252/252 [==============================] - 19s 75ms/step - loss: 6.6787e-04 - ssim: 0.9535 - val_loss: 0.0014 - val_ssim: 0.9642
# Epoch 53/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5839e-04 - ssim: 0.9524
# Epoch 53: loss did not improve from 0.00066
# 252/252 [==============================] - 18s 73ms/step - loss: 6.5839e-04 - ssim: 0.9524 - val_loss: 0.0014 - val_ssim: 0.9545
# Epoch 54/100
# 252/252 [==============================] - ETA: 0s - loss: 9.5354e-04 - ssim: 0.9487
# Epoch 54: loss did not improve from 0.00066
# 252/252 [==============================] - 16s 63ms/step - loss: 9.5354e-04 - ssim: 0.9487 - val_loss: 0.0018 - val_ssim: 0.9586
# Epoch 55/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6713e-04 - ssim: 0.9525
# Epoch 55: loss did not improve from 0.00066
# 252/252 [==============================] - 19s 75ms/step - loss: 6.6713e-04 - ssim: 0.9525 - val_loss: 0.0016 - val_ssim: 0.9630
# Epoch 56/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5023e-04 - ssim: 0.9531
# Epoch 56: loss improved from 0.00066 to 0.00065, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 18s 74ms/step - loss: 6.5023e-04 - ssim: 0.9531 - val_loss: 0.0037 - val_ssim: 0.9556
# Epoch 57/100
# 252/252 [==============================] - ETA: 0s - loss: 6.3334e-04 - ssim: 0.9540
# Epoch 57: loss improved from 0.00065 to 0.00063, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 17s 67ms/step - loss: 6.3334e-04 - ssim: 0.9540 - val_loss: 0.0011 - val_ssim: 0.9612
# Epoch 58/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4470e-04 - ssim: 0.9551
# Epoch 58: loss did not improve from 0.00063
# 252/252 [==============================] - 18s 72ms/step - loss: 6.4470e-04 - ssim: 0.9551 - val_loss: 0.0013 - val_ssim: 0.9586
# Epoch 59/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5158e-04 - ssim: 0.9545
# Epoch 59: loss did not improve from 0.00063
# 252/252 [==============================] - 16s 64ms/step - loss: 6.5158e-04 - ssim: 0.9545 - val_loss: 0.0011 - val_ssim: 0.9577
# Epoch 60/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.6550e-04 - ssim: 0.9545
# Epoch 60: loss did not improve from 0.00063
# 252/252 [==============================] - 18s 72ms/step - loss: 6.6518e-04 - ssim: 0.9545 - val_loss: 0.0011 - val_ssim: 0.9632
# Epoch 61/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2061e-04 - ssim: 0.9564
# Epoch 61: loss improved from 0.00063 to 0.00062, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 16s 65ms/step - loss: 6.2061e-04 - ssim: 0.9564 - val_loss: 0.0029 - val_ssim: 0.9568
# Epoch 62/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2713e-04 - ssim: 0.9574
# Epoch 62: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 6.2713e-04 - ssim: 0.9574 - val_loss: 0.0011 - val_ssim: 0.9633
# Epoch 63/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5393e-04 - ssim: 0.9570
# Epoch 63: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 63ms/step - loss: 6.5393e-04 - ssim: 0.9570 - val_loss: 0.0021 - val_ssim: 0.9581
# Epoch 64/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5463e-04 - ssim: 0.9563
# Epoch 64: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 66ms/step - loss: 6.5463e-04 - ssim: 0.9563 - val_loss: 0.0035 - val_ssim: 0.9575
# Epoch 65/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0022 - ssim: 0.9363
# Epoch 65: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 0.0022 - ssim: 0.9363 - val_loss: 0.0105 - val_ssim: 0.9132
# Epoch 66/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0014 - ssim: 0.9376
# Epoch 66: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 65ms/step - loss: 0.0014 - ssim: 0.9377 - val_loss: 0.0013 - val_ssim: 0.9627
# Epoch 67/100
# 252/252 [==============================] - ETA: 0s - loss: 9.7167e-04 - ssim: 0.9429
# Epoch 67: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 63ms/step - loss: 9.7167e-04 - ssim: 0.9429 - val_loss: 0.0014 - val_ssim: 0.9594
# Epoch 68/100
# 252/252 [==============================] - ETA: 0s - loss: 7.3471e-04 - ssim: 0.9490
# Epoch 68: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 74ms/step - loss: 7.3471e-04 - ssim: 0.9490 - val_loss: 0.0016 - val_ssim: 0.9595
# Epoch 69/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0774e-04 - ssim: 0.9503
# Epoch 69: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 7.0774e-04 - ssim: 0.9503 - val_loss: 0.0015 - val_ssim: 0.9599
# Epoch 70/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.9181e-04 - ssim: 0.9515
# Epoch 70: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 75ms/step - loss: 6.9200e-04 - ssim: 0.9515 - val_loss: 0.0015 - val_ssim: 0.9610
# Epoch 71/100
# 252/252 [==============================] - ETA: 0s - loss: 6.3716e-04 - ssim: 0.9519
# Epoch 71: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 6.3716e-04 - ssim: 0.9519 - val_loss: 0.0021 - val_ssim: 0.9600
# Epoch 72/100
# 252/252 [==============================] - ETA: 0s - loss: 6.7158e-04 - ssim: 0.9512
# Epoch 72: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 6.7158e-04 - ssim: 0.9512 - val_loss: 0.0024 - val_ssim: 0.9584
# Epoch 73/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5409e-04 - ssim: 0.9529
# Epoch 73: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 65ms/step - loss: 6.5409e-04 - ssim: 0.9529 - val_loss: 0.0017 - val_ssim: 0.9606
# Epoch 74/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.6426e-04 - ssim: 0.9502
# Epoch 74: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 6.6304e-04 - ssim: 0.9503 - val_loss: 0.0204 - val_ssim: 0.9612
# Epoch 75/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5167e-04 - ssim: 0.9530
# Epoch 75: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 74ms/step - loss: 6.5167e-04 - ssim: 0.9530 - val_loss: 0.5383 - val_ssim: 0.9576
# Epoch 76/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8275e-04 - ssim: 0.9526
# Epoch 76: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 6.8275e-04 - ssim: 0.9526 - val_loss: 101.9713 - val_ssim: 0.9589
# Epoch 77/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2293e-04 - ssim: 0.9528
# Epoch 77: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 65ms/step - loss: 6.2293e-04 - ssim: 0.9528 - val_loss: 0.0015 - val_ssim: 0.9603
# Epoch 78/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0020 - ssim: 0.9305
# Epoch 78: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 0.0020 - ssim: 0.9305 - val_loss: 0.0057 - val_ssim: 0.9190
# Epoch 79/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0017 - ssim: 0.9049
# Epoch 79: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 0.0017 - ssim: 0.9049 - val_loss: 0.0019 - val_ssim: 0.9377
# Epoch 80/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9164
# Epoch 80: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 75ms/step - loss: 0.0012 - ssim: 0.9164 - val_loss: 0.0017 - val_ssim: 0.9405
# Epoch 81/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9238
# Epoch 81: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 63ms/step - loss: 0.0011 - ssim: 0.9238 - val_loss: 0.0029 - val_ssim: 0.9380
# Epoch 82/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9292
# Epoch 82: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 74ms/step - loss: 0.0010 - ssim: 0.9292 - val_loss: 0.0035 - val_ssim: 0.9392
# Epoch 83/100
# 252/252 [==============================] - ETA: 0s - loss: 9.5447e-04 - ssim: 0.9326
# Epoch 83: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 9.5447e-04 - ssim: 0.9326 - val_loss: 0.0015 - val_ssim: 0.9521
# Epoch 84/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.7743e-04 - ssim: 0.9445
# Epoch 84: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 65ms/step - loss: 7.7715e-04 - ssim: 0.9445 - val_loss: 0.0023 - val_ssim: 0.9544
# Epoch 85/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4402e-04 - ssim: 0.9493
# Epoch 85: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 7.4402e-04 - ssim: 0.9493 - val_loss: 0.0021 - val_ssim: 0.9563
# Epoch 86/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0625e-04 - ssim: 0.9504
# Epoch 86: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 75ms/step - loss: 7.0625e-04 - ssim: 0.9504 - val_loss: 0.0029 - val_ssim: 0.9335
# Epoch 87/100
# 252/252 [==============================] - ETA: 0s - loss: 7.3508e-04 - ssim: 0.9508
# Epoch 87: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 7.3508e-04 - ssim: 0.9508 - val_loss: 0.0039 - val_ssim: 0.9374
# Epoch 88/100
# 252/252 [==============================] - ETA: 0s - loss: 6.9930e-04 - ssim: 0.9500
# Epoch 88: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 64ms/step - loss: 6.9930e-04 - ssim: 0.9500 - val_loss: 0.0021 - val_ssim: 0.9494
# Epoch 89/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8908e-04 - ssim: 0.9526
# Epoch 89: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 65ms/step - loss: 6.8908e-04 - ssim: 0.9526 - val_loss: 0.0068 - val_ssim: 0.9315
# Epoch 90/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0641e-04 - ssim: 0.9522
# Epoch 90: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 7.0641e-04 - ssim: 0.9522 - val_loss: 0.0030 - val_ssim: 0.9450
# Epoch 91/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8117e-04 - ssim: 0.9522
# Epoch 91: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 74ms/step - loss: 6.8117e-04 - ssim: 0.9522 - val_loss: 0.0015 - val_ssim: 0.9522
# Epoch 92/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8806e-04 - ssim: 0.9531
# Epoch 92: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 6.8806e-04 - ssim: 0.9531 - val_loss: 0.0022 - val_ssim: 0.9510
# Epoch 93/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6266e-04 - ssim: 0.9539
# Epoch 93: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 76ms/step - loss: 6.6266e-04 - ssim: 0.9539 - val_loss: 0.0023 - val_ssim: 0.9476
# Epoch 94/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4836e-04 - ssim: 0.9537
# Epoch 94: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 72ms/step - loss: 6.4836e-04 - ssim: 0.9537 - val_loss: 0.0019 - val_ssim: 0.9538
# Epoch 95/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6259e-04 - ssim: 0.9524
# Epoch 95: loss did not improve from 0.00062
# 252/252 [==============================] - 18s 73ms/step - loss: 6.6259e-04 - ssim: 0.9524 - val_loss: 0.0017 - val_ssim: 0.9562
# Epoch 96/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.4809e-04 - ssim: 0.9524
# Epoch 96: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 75ms/step - loss: 6.4754e-04 - ssim: 0.9525 - val_loss: 0.0015 - val_ssim: 0.9567
# Epoch 97/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4056e-04 - ssim: 0.9538
# Epoch 97: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 63ms/step - loss: 6.4056e-04 - ssim: 0.9538 - val_loss: 0.0021 - val_ssim: 0.9570
# Epoch 98/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4277e-04 - ssim: 0.9531
# Epoch 98: loss did not improve from 0.00062
# 252/252 [==============================] - 16s 66ms/step - loss: 6.4277e-04 - ssim: 0.9531 - val_loss: 2404744.2500 - val_ssim: 0.4950
# Epoch 99/100
# 252/252 [==============================] - ETA: 0s - loss: 6.1991e-04 - ssim: 0.9538
# Epoch 99: loss improved from 0.00062 to 0.00062, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 19s 74ms/step - loss: 6.1991e-04 - ssim: 0.9538 - val_loss: 0.0021 - val_ssim: 0.9537
# Epoch 100/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5225e-04 - ssim: 0.9528
# Epoch 100: loss did not improve from 0.00062
# 252/252 [==============================] - 19s 75ms/step - loss: 6.5225e-04 - ssim: 0.9528 - val_loss: 0.0074 - val_ssim: 0.9603

# %%
import pickle
with open('/kaggle/working/history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
print(type(history.history))
# Out:
# <class 'dict'>

# %%
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)
  
dependencies = {
    'ssim': ssim
}

# %%
#model = keras.models.load_model('/kaggle/working/unet4.h5', custom_objects=dependencies)
model = keras.models.load_model('/kaggle/input/unetmodel1/4encoder_base512_model.h5', custom_objects=dependencies)

# %%
import pickle
with open('/kaggle/working/history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
import seaborn as sns
sns.set_style('dark')

# %%
plt.figure(figsize=(20,8))
loss = history['loss']
val_loss = history['val_loss']
length = len(loss)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
#plt.xticks(range(16), range(5,21))

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(history['ssim'])
plt.plot(history['val_ssim'])
plt.title('SSIM')
plt.ylabel('ssim')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
random_val_samples = val_generator1.__next__()
val_image_samples = random_val_samples[0]
val_mask_samples = random_val_samples[1]
predicted_masks = model.predict(val_image_samples)

# %%
fig, axs = plt.subplots(1 , 3, figsize=(20,4))
axs[0].imshow(random_val_samples[0][0])
axs[0].set_title('Input Image')
axs[1].imshow(val_mask_samples[0])
axs[1].set_title('Actual Image')
axs[2].imshow(predicted_masks[0])
axs[2].set_title('Reconstructed Image')

print(predicted_masks[0].shape)
print(val_mask_samples[0].shape)
print(random_val_samples[0][0].shape)
#cv2.imwrite(op_path + '/train_img.jpg',t_image)
#cv2.imwrite(op_path + '/actual_img.jpg', a_image)
#cv2.imwrite(op_path + '/predicted.jpg', image)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)

# %%
# p_image = (predicted_masks[0] * 255).astype(np.uint8)
# a_image = (val_mask_samples[0] * 255).astype(np.uint8)
# t_image = (random_val_samples[0][0] * 255).astype(np.uint8)

# %%
# generate image dataset
img_dim = 256
batch_sz = 1
image_datagen = ImageDataGenerator(rescale=1./255)
mask_datagen = ImageDataGenerator(rescale=1./255)
#print(image_datagen.shape)

test_image_generator = image_datagen.flow_from_directory(
        test_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['vary_thick'],
        # color_mode=,
        batch_size = batch_sz,
        seed=42,
        subset='training')
    
test_mask_generator = mask_datagen.flow_from_directory(
        test_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images'],
        batch_size = batch_sz,
        seed=42,
        subset='training')

#image_datagen = ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
#mask_datagen = ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
# train_generator = zip(train_image_generator, train_mask_generator)
# val_generator = zip(val_image_generator, val_mask_generator)
test_generator = zip(test_image_generator, test_mask_generator)
# Out:
# Found 303 images belonging to 1 classes.
# Found 303 images belonging to 1 classes.

# %%
Ssim = []
n = 0
for i,m in test_generator:
    if n<304:
        img,mask = i,m
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        #print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        Ssim.append(acc)
        n=n+1
    else:
        break
# Out:
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step

# %%
print(np.average(Ssim))
# Out:
# 0.89356893

# %%
fig, ax = plt.subplots()

# Create a boxplot
ax.boxplot(Ssim)

# Set axis labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Boxplot of Data')

# Show the plot
plt.show()

# %%
Ssim = []
n = 0
for i,m in test_generator:
    img,mask = i,m
    if n<5:
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        image1_array = mask[0]  # Get the NumPy array directly from the mask
        image2_array = pred[0]
        
        #image1_gray = mask[0].convert("L")
        #image2_gray = pred[0].convert("L")

# Convert the images to numpy arrays
        #image1_array = np.array(image1_gray)
        #image2_array = np.array(image2_gray)

# Compute the absolute difference between the two images
        diff_array = np.abs(image1_array - image2_array)
        #diff_array[0][3] = 1

# Find the maximum and minimum values in the difference matrix
        max_value = np.max(diff_array)
        min_value = np.min(diff_array)
        print(max_value)
        print(min_value)
        #max_value = 1
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))
        axes[0].imshow(mask[0])
        axes[0].set_title("Actual")
        axes[1].imshow(pred[0])
        axes[1].set_title("Predicted")
        im = axes[2].imshow(diff_array, cmap="gray", vmax=max_value, vmin=min_value)
        axes[2].set_title("Difference")
        plt.colorbar(im, ax=axes[2])

        # Display the plot
        plt.show()
        n+=1
    else:
        break
# Out:
# 1/1 [==============================] - 0s 25ms/step
# SSIM: 0.8908019065856934
# 0.4666667
# 1.1920929e-07
# 1/1 [==============================] - 0s 28ms/step
# SSIM: 0.8920209407806396
# 0.454902
# 4.172325e-07
# 1/1 [==============================] - 0s 29ms/step
# SSIM: 0.8921617865562439
# 0.454902
# 2.3841858e-07
# 1/1 [==============================] - 0s 30ms/step
# SSIM: 0.8927149772644043
# 0.46274513
# 2.9802322e-08
# 1/1 [==============================] - 0s 28ms/step
# SSIM: 0.8986065983772278
# 0.454902
# 1.1920929e-07
