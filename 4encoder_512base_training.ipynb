# %% [markdown]
# #Imports and path setup

# %%
# imports
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import os
#from google.colab.patches import cv_imshow
import cv2
import imgaug 
import imgaug as ia
import imgaug.augmenters as iaa
from sklearn.model_selection import train_test_split
import random
import shutil

# %%
# define paths
bmp_path = '/kaggle/input'
op_path = '/kaggle/working'
circle_path = bmp_path + '/circles_new'
bamboo_path = bmp_path + '/bamboo'
image_path = bmp_path + '/minorproject'
train_image_path = image_path + '/train_images_latest'
true_image_path = image_path + '/true_images_new'
raw_masks_path = f"{bmp_path}/raw_masks_new/"
masks_path = f"{bmp_path}/masks_new/"

# %%
X = np.array(list(map(lambda a : image_path + '/' + a, os.listdir(image_path))))
y = np.array(list(map(lambda a : true_image_path + '/' + a, os.listdir(true_image_path))))

# %%
print(X.shape)
# Out:
# (2,)

# %%
print(y.shape)
# Out:
# (2525,)

# %%
os.makedirs('/kaggle/working/random_images')

# %%
# initialising diversity array
diversity = np.zeros((505, 505))

# %%
from skimage.metrics import structural_similarity as ssim

# %%
# get a list of all image files in source directory
num_images = 505
images = os.listdir(train_image_path)
selected_images = random.sample(images, num_images)
des_dir = '/kaggle/working/random_images'
# initialize a counter for the new file names
counter = 1

# loop through the images and copy them to the destination directory with a new name
for img_file in selected_images:
    # construct the new file name with the counter
    new_name = f'random_image_{counter}.jpg'
    # copy the file to the destination directory with the new name
    shutil.copy(os.path.join(train_image_path, img_file), os.path.join(des_dir, new_name))
    # increment the counter
    counter += 1

# %%
dvsrty1 = dvsrty[:20]

# %%
plt.plot(dvsrty)

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of dvsrty')

# Show the plot
plt.show()

# %%
plt.plot(dvsrty1)

# Add labels and title
plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Plot of dvsrty')

# Show the plot
plt.show()

# %% [markdown]
# #Model

# %%
fig, ax = plt.subplots()

# Create a boxplot
ax.boxplot(dvsrty)

# Set axis labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Boxplot of Data')

# Show the plot
plt.show()

# %% [markdown]
# ## Image generator

# %%
# function for normalization
def normalize(input_image):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  # input_mask = tf.cast(input_mask, tf.float32) / 255.0
  return input_image

# %%
# generate image dataset
img_dim = 256
batch_sz = 1
image_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2)
mask_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2)
#print(image_datagen.shape)

train_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode=,
        batch_size = batch_sz,
        seed=42,
        subset='training')
    
train_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        batch_size = batch_sz,
        seed=42,
        subset='training')

val_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')
    
val_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')


train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 2020 images belonging to 1 classes.
# Found 2020 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.

# %%
training_samples_size = train_image_generator.samples
val_samples_size = val_image_generator.samples
print(training_samples_size)
print(val_samples_size)
# Out:
# 2020
# 505

# %% [markdown]
# ##U-Net

# %%
# batch/buffer sizes for NN
BATCH_SIZE = 8
BUFFER_SIZE = 1000
# train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# validation_batches = test_dataset.take(3000).batch(BATCH_SIZE)
# test_batches = test_dataset.skip(3000).take(669).batch(BATCH_SIZE)

# %%
# custom convolution
def conv_block(input, num_filters):
  # First Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(input)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  # Second Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(x)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  
  return x

# %%
# custom encoder
def encoder_block(input, num_filters):
  x = conv_block(input, num_filters)
  p = layers.MaxPool2D(2)(x)

  return x, p

# %%
# custom decoder
def decoder_block(input, skip_features, num_filters):
  x = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')(input)
  x = layers.Concatenate()([skip_features, x])
  x = layers.Dropout(0.3)(x)
  x = conv_block(x, num_filters)

  return x

# %%
# function to build unet
def build_unet_model(input_shape):
  inputs = layers.Input(shape=input_shape)

  # Encoders
  #s1, p1 = encoder_block(inputs,8)
  #s1, p1= encoder_block(inputs,16)
  s1, p1= encoder_block(inputs,32)
  s2, p2= encoder_block(p1,64)
  s3, p3= encoder_block(p2,128)
  s4, p4= encoder_block(p3, 256)
  #s6, p6= encoder_block(p5, 512)
  # s5, p6 = encoder_block(p4, 1024)

  # Base
  b = conv_block(p4, 512)

  # Decoders
  # d = decoder_block(b, s5, 1024)
  #d1 = decoder_block(b, s6, 512)
  d1 = decoder_block(b, s4, 256)
  d2 = decoder_block(d1,s3,128)
  d3 = decoder_block(d2,s2,64)
  d4 = decoder_block(d3, s1, 32)
  #d6 = decoder_block(d5, s1, 16)
  #d6 = decoder_block(d5, s1, 8)
  

  # Output
  outputs = layers.Conv2D(3, 3, padding='same', activation='relu')(d4)

  # UNet model 
  unet_model = keras.Model(inputs, outputs, name='U-Net')

  return unet_model

# %%
#SSIM metrics
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)

def ape(y_true, y_pred):
  return tf.keras.losses.MeanAbsolutePercentageError(y_true, y_pred)

# %%
# build model
unet_model = build_unet_model((img_dim, img_dim, 3))

# %%
# unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
#                   loss="MSE",
#                   metrics=[ssim, tf.keras.metrics.MeanAbsolutePercentageError()])
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss="MSE",
                  metrics=[ssim])

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 32  896         ['input_1[0][0]']
#                                 )
#
#  activation (Activation)        (None, 256, 256, 32  0           ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 256, 256, 32  128        ['activation[0][0]']
#  alization)                     )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 32  9248        ['batch_normalization[0][0]']
#                                 )
#
#  activation_1 (Activation)      (None, 256, 256, 32  0           ['conv2d_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 256, 256, 32  128        ['activation_1[0][0]']
#  rmalization)                   )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 32  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  activation_2 (Activation)      (None, 128, 128, 64  0           ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_2 (BatchNo  (None, 128, 128, 64  256        ['activation_2[0][0]']
#  rmalization)                   )
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 64  36928       ['batch_normalization_2[0][0]']
#                                 )
#
#  activation_3 (Activation)      (None, 128, 128, 64  0           ['conv2d_3[0][0]']
#                                 )
#
#  batch_normalization_3 (BatchNo  (None, 128, 128, 64  256        ['activation_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d_1[0][0]']
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['conv2d_4[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['activation_4[0][0]']
#  rmalization)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 128)  147584      ['batch_normalization_4[0][0]']
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['conv2d_5[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['activation_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  activation_6 (Activation)      (None, 32, 32, 256)  0           ['conv2d_6[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 256)  1024       ['activation_6[0][0]']
#  rmalization)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 256)  590080      ['batch_normalization_6[0][0]']
#
#  activation_7 (Activation)      (None, 32, 32, 256)  0           ['conv2d_7[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 32, 32, 256)  1024       ['activation_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 512)  0           ['conv2d_8[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 16, 16, 512)  2048       ['activation_8[0][0]']
#  rmalization)
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 512)  2359808     ['batch_normalization_8[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 512)  0           ['conv2d_9[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 16, 16, 512)  2048       ['activation_9[0][0]']
#  rmalization)
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 256)  1179904    ['batch_normalization_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 512)  0           ['batch_normalization_7[0][0]',
#                                                                   'conv2d_transpose[0][0]']
#
#  dropout (Dropout)              (None, 32, 32, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 256)  1179904     ['dropout[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 256)  0           ['conv2d_10[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 32, 32, 256)  1024       ['activation_10[0][0]']
#  ormalization)
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 256)  0           ['conv2d_11[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 256)  1024       ['activation_11[0][0]']
#  ormalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 128)  295040     ['batch_normalization_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 256)  0           ['batch_normalization_5[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 128)  295040      ['dropout_1[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 128)  0           ['conv2d_12[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 64, 64, 128)  512        ['activation_12[0][0]']
#  ormalization)
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_12[0][0]']
#
#  activation_13 (Activation)     (None, 64, 64, 128)  0           ['conv2d_13[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 64, 64, 128)  512        ['activation_13[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 64  73792      ['batch_normalization_13[0][0]']
#  spose)                         )
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 12  0           ['batch_normalization_3[0][0]',
#                                 8)                                'conv2d_transpose_2[0][0]']
#
#  dropout_2 (Dropout)            (None, 128, 128, 12  0           ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 64  73792       ['dropout_2[0][0]']
#                                 )
#
#  activation_14 (Activation)     (None, 128, 128, 64  0           ['conv2d_14[0][0]']
#                                 )
#
#  batch_normalization_14 (BatchN  (None, 128, 128, 64  256        ['activation_14[0][0]']
#  ormalization)                  )
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_14[0][0]']
#                                 )
#
#  activation_15 (Activation)     (None, 128, 128, 64  0           ['conv2d_15[0][0]']
#                                 )
#
#  batch_normalization_15 (BatchN  (None, 128, 128, 64  256        ['activation_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 32  18464      ['batch_normalization_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 64  0           ['batch_normalization_1[0][0]',
#                                 )                                 'conv2d_transpose_3[0][0]']
#
#  dropout_3 (Dropout)            (None, 256, 256, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 32  18464       ['dropout_3[0][0]']
#                                 )
#
#  activation_16 (Activation)     (None, 256, 256, 32  0           ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 256, 256, 32  128        ['activation_16[0][0]']
#  ormalization)                  )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_16[0][0]']
#                                 )
#
#  activation_17 (Activation)     (None, 256, 256, 32  0           ['conv2d_17[0][0]']
#                                 )
#
#  batch_normalization_17 (BatchN  (None, 256, 256, 32  128        ['activation_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 3)  867         ['batch_normalization_17[0][0]']
#
# ==================================================================================================
# Total params: 8,643,107
# Trainable params: 8,637,219
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# save model
model_path = op_path + "/unet4.h5"
checkpoint = keras.callbacks.ModelCheckpoint(model_path,
                             monitor="loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

# earlystop = keras.callbacks.EarlyStopping(monitor = 'loss', 
#                           min_delta = 0, 
#                           patience = 5,
#                           verbose = 1,
#                           restore_best_weights = True)

# %%
history = unet_model.fit(train_generator,
                    steps_per_epoch=training_samples_size//BATCH_SIZE,
                    validation_data=val_generator,
                    validation_steps=val_samples_size//BATCH_SIZE,
                    epochs=100, callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 2023-04-25 07:45:34.129967: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 251/252 [============================>.] - ETA: 0s - loss: 0.0440 - ssim: 0.6262
# Epoch 1: loss improved from inf to 0.04384, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 29s 42ms/step - loss: 0.0438 - ssim: 0.6268 - val_loss: 0.2784 - val_ssim: 0.0586
# Epoch 2/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0037 - ssim: 0.8190
# Epoch 2: loss improved from 0.04384 to 0.00369, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0037 - ssim: 0.8190 - val_loss: 0.0126 - val_ssim: 0.8576
# Epoch 3/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0023 - ssim: 0.8522
# Epoch 3: loss improved from 0.00369 to 0.00225, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 12s 46ms/step - loss: 0.0023 - ssim: 0.8522 - val_loss: 0.0024 - val_ssim: 0.8969
# Epoch 4/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0018 - ssim: 0.8673
# Epoch 4: loss improved from 0.00225 to 0.00184, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 43ms/step - loss: 0.0018 - ssim: 0.8673 - val_loss: 0.0018 - val_ssim: 0.9007
# Epoch 5/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0016 - ssim: 0.8790
# Epoch 5: loss improved from 0.00184 to 0.00163, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 44ms/step - loss: 0.0016 - ssim: 0.8790 - val_loss: 0.0014 - val_ssim: 0.9044
# Epoch 6/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0016 - ssim: 0.8862
# Epoch 6: loss improved from 0.00163 to 0.00157, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 12s 46ms/step - loss: 0.0016 - ssim: 0.8862 - val_loss: 0.0018 - val_ssim: 0.9082
# Epoch 7/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0015 - ssim: 0.8953
# Epoch 7: loss improved from 0.00157 to 0.00147, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 44ms/step - loss: 0.0015 - ssim: 0.8953 - val_loss: 0.0016 - val_ssim: 0.9144
# Epoch 8/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0014 - ssim: 0.9016
# Epoch 8: loss improved from 0.00147 to 0.00141, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0014 - ssim: 0.9016 - val_loss: 0.0014 - val_ssim: 0.9249
# Epoch 9/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0014 - ssim: 0.9089
# Epoch 9: loss improved from 0.00141 to 0.00136, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 41ms/step - loss: 0.0014 - ssim: 0.9089 - val_loss: 0.0016 - val_ssim: 0.9278
# Epoch 10/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0013 - ssim: 0.9163
# Epoch 10: loss improved from 0.00136 to 0.00129, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0013 - ssim: 0.9164 - val_loss: 0.0013 - val_ssim: 0.9360
# Epoch 11/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0013 - ssim: 0.9189
# Epoch 11: loss improved from 0.00129 to 0.00127, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0013 - ssim: 0.9189 - val_loss: 0.0019 - val_ssim: 0.9365
# Epoch 12/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9226
# Epoch 12: loss improved from 0.00127 to 0.00122, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0012 - ssim: 0.9226 - val_loss: 0.0021 - val_ssim: 0.9393
# Epoch 13/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0028 - ssim: 0.9147
# Epoch 13: loss did not improve from 0.00122
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0028 - ssim: 0.9143 - val_loss: 4664.0166 - val_ssim: 9.6017e-05
# Epoch 14/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0033 - ssim: 0.8868
# Epoch 14: loss did not improve from 0.00122
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0033 - ssim: 0.8869 - val_loss: 0.0030 - val_ssim: 0.9001
# Epoch 15/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0013 - ssim: 0.9145
# Epoch 15: loss did not improve from 0.00122
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0013 - ssim: 0.9145 - val_loss: 0.0013 - val_ssim: 0.9382
# Epoch 16/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0012 - ssim: 0.9234
# Epoch 16: loss improved from 0.00122 to 0.00120, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0012 - ssim: 0.9234 - val_loss: 0.0014 - val_ssim: 0.9407
# Epoch 17/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0012 - ssim: 0.9243
# Epoch 17: loss improved from 0.00120 to 0.00120, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0012 - ssim: 0.9242 - val_loss: 0.0015 - val_ssim: 0.9376
# Epoch 18/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9285
# Epoch 18: loss improved from 0.00120 to 0.00113, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0011 - ssim: 0.9285 - val_loss: 0.0013 - val_ssim: 0.9429
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9296
# Epoch 19: loss improved from 0.00113 to 0.00112, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0011 - ssim: 0.9296 - val_loss: 0.0014 - val_ssim: 0.9443
# Epoch 20/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0011 - ssim: 0.9334
# Epoch 20: loss improved from 0.00112 to 0.00106, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0011 - ssim: 0.9334 - val_loss: 0.0013 - val_ssim: 0.9483
# Epoch 21/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0011 - ssim: 0.9339
# Epoch 21: loss improved from 0.00106 to 0.00105, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0011 - ssim: 0.9339 - val_loss: 0.0012 - val_ssim: 0.9481
# Epoch 22/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9358
# Epoch 22: loss improved from 0.00105 to 0.00103, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 0.0010 - ssim: 0.9358 - val_loss: 0.0012 - val_ssim: 0.9522
# Epoch 23/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9326
# Epoch 23: loss did not improve from 0.00103
# 252/252 [==============================] - 9s 37ms/step - loss: 0.0011 - ssim: 0.9326 - val_loss: 0.0082 - val_ssim: 0.9078
# Epoch 24/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0012 - ssim: 0.9330
# Epoch 24: loss did not improve from 0.00103
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0012 - ssim: 0.9329 - val_loss: 0.0016 - val_ssim: 0.9460
# Epoch 25/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0011 - ssim: 0.9360
# Epoch 25: loss did not improve from 0.00103
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0011 - ssim: 0.9361 - val_loss: 0.0016 - val_ssim: 0.9485
# Epoch 26/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9353
# Epoch 26: loss did not improve from 0.00103
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0011 - ssim: 0.9353 - val_loss: 0.0012 - val_ssim: 0.9493
# Epoch 27/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9377
# Epoch 27: loss improved from 0.00103 to 0.00102, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0010 - ssim: 0.9377 - val_loss: 0.0012 - val_ssim: 0.9505
# Epoch 28/100
# 251/252 [============================>.] - ETA: 0s - loss: 0.0010 - ssim: 0.9365
# Epoch 28: loss did not improve from 0.00102
# 252/252 [==============================] - 9s 36ms/step - loss: 0.0010 - ssim: 0.9364 - val_loss: 0.0017 - val_ssim: 0.9505
# Epoch 29/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9362
# Epoch 29: loss did not improve from 0.00102
# 252/252 [==============================] - 10s 38ms/step - loss: 0.0010 - ssim: 0.9362 - val_loss: 0.0031 - val_ssim: 0.9188
# Epoch 30/100
# 251/252 [============================>.] - ETA: 0s - loss: 9.6061e-04 - ssim: 0.9388
# Epoch 30: loss improved from 0.00102 to 0.00096, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 9.6135e-04 - ssim: 0.9388 - val_loss: 0.0012 - val_ssim: 0.9542
# Epoch 31/100
# 251/252 [============================>.] - ETA: 0s - loss: 9.1550e-04 - ssim: 0.9419
# Epoch 31: loss improved from 0.00096 to 0.00092, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 9.1595e-04 - ssim: 0.9418 - val_loss: 0.0014 - val_ssim: 0.9556
# Epoch 32/100
# 252/252 [==============================] - ETA: 0s - loss: 9.4249e-04 - ssim: 0.9404
# Epoch 32: loss did not improve from 0.00092
# 252/252 [==============================] - 11s 43ms/step - loss: 9.4249e-04 - ssim: 0.9404 - val_loss: 0.0013 - val_ssim: 0.9489
# Epoch 33/100
# 252/252 [==============================] - ETA: 0s - loss: 9.1916e-04 - ssim: 0.9420
# Epoch 33: loss did not improve from 0.00092
# 252/252 [==============================] - 9s 37ms/step - loss: 9.1916e-04 - ssim: 0.9420 - val_loss: 0.0021 - val_ssim: 0.9328
# Epoch 34/100
# 251/252 [============================>.] - ETA: 0s - loss: 9.0957e-04 - ssim: 0.9437
# Epoch 34: loss improved from 0.00092 to 0.00091, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 9.1022e-04 - ssim: 0.9437 - val_loss: 0.0039 - val_ssim: 0.9049
# Epoch 35/100
# 251/252 [============================>.] - ETA: 0s - loss: 8.6959e-04 - ssim: 0.9460
# Epoch 35: loss improved from 0.00091 to 0.00087, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 8.7083e-04 - ssim: 0.9459 - val_loss: 0.0015 - val_ssim: 0.9365
# Epoch 36/100
# 251/252 [============================>.] - ETA: 0s - loss: 8.8137e-04 - ssim: 0.9456
# Epoch 36: loss did not improve from 0.00087
# 252/252 [==============================] - 11s 44ms/step - loss: 8.8156e-04 - ssim: 0.9456 - val_loss: 0.0016 - val_ssim: 0.9358
# Epoch 37/100
# 251/252 [============================>.] - ETA: 0s - loss: 8.8122e-04 - ssim: 0.9461
# Epoch 37: loss did not improve from 0.00087
# 252/252 [==============================] - 9s 37ms/step - loss: 8.8105e-04 - ssim: 0.9461 - val_loss: 0.0017 - val_ssim: 0.9420
# Epoch 38/100
# 252/252 [==============================] - ETA: 0s - loss: 8.5848e-04 - ssim: 0.9479
# Epoch 38: loss improved from 0.00087 to 0.00086, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 8.5848e-04 - ssim: 0.9479 - val_loss: 0.0016 - val_ssim: 0.9377
# Epoch 39/100
# 251/252 [============================>.] - ETA: 0s - loss: 8.0604e-04 - ssim: 0.9509
# Epoch 39: loss improved from 0.00086 to 0.00081, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 8.0631e-04 - ssim: 0.9509 - val_loss: 0.0010 - val_ssim: 0.9391
# Epoch 40/100
# 251/252 [============================>.] - ETA: 0s - loss: 8.2190e-04 - ssim: 0.9500
# Epoch 40: loss did not improve from 0.00081
# 252/252 [==============================] - 9s 37ms/step - loss: 8.2213e-04 - ssim: 0.9500 - val_loss: 0.0014 - val_ssim: 0.9424
# Epoch 41/100
# 252/252 [==============================] - ETA: 0s - loss: 8.0891e-04 - ssim: 0.9511
# Epoch 41: loss did not improve from 0.00081
# 252/252 [==============================] - 9s 36ms/step - loss: 8.0891e-04 - ssim: 0.9511 - val_loss: 0.0012 - val_ssim: 0.9457
# Epoch 42/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.7244e-04 - ssim: 0.9529
# Epoch 42: loss improved from 0.00081 to 0.00077, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 7.7267e-04 - ssim: 0.9529 - val_loss: 0.0012 - val_ssim: 0.9423
# Epoch 43/100
# 252/252 [==============================] - ETA: 0s - loss: 7.8551e-04 - ssim: 0.9525
# Epoch 43: loss did not improve from 0.00077
# 252/252 [==============================] - 9s 37ms/step - loss: 7.8551e-04 - ssim: 0.9525 - val_loss: 0.0013 - val_ssim: 0.9425
# Epoch 44/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.8936e-04 - ssim: 0.9518
# Epoch 44: loss did not improve from 0.00077
# 252/252 [==============================] - 11s 42ms/step - loss: 7.8962e-04 - ssim: 0.9518 - val_loss: 0.0015 - val_ssim: 0.9436
# Epoch 45/100
# 252/252 [==============================] - ETA: 0s - loss: 7.7533e-04 - ssim: 0.9520
# Epoch 45: loss did not improve from 0.00077
# 252/252 [==============================] - 11s 43ms/step - loss: 7.7533e-04 - ssim: 0.9520 - val_loss: 0.0015 - val_ssim: 0.9386
# Epoch 46/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6428e-04 - ssim: 0.9524
# Epoch 46: loss improved from 0.00077 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 7.6428e-04 - ssim: 0.9524 - val_loss: 0.0016 - val_ssim: 0.9380
# Epoch 47/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.6016e-04 - ssim: 0.9533
# Epoch 47: loss improved from 0.00076 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 7.5862e-04 - ssim: 0.9534 - val_loss: 0.0015 - val_ssim: 0.9411
# Epoch 48/100
# 252/252 [==============================] - ETA: 0s - loss: 7.5031e-04 - ssim: 0.9529
# Epoch 48: loss improved from 0.00076 to 0.00075, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 39ms/step - loss: 7.5031e-04 - ssim: 0.9529 - val_loss: 0.0015 - val_ssim: 0.9390
# Epoch 49/100
# 252/252 [==============================] - ETA: 0s - loss: 7.3815e-04 - ssim: 0.9545
# Epoch 49: loss improved from 0.00075 to 0.00074, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 7.3815e-04 - ssim: 0.9545 - val_loss: 0.0015 - val_ssim: 0.9393
# Epoch 50/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.0747e-04 - ssim: 0.9560
# Epoch 50: loss improved from 0.00074 to 0.00071, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 7.0779e-04 - ssim: 0.9559 - val_loss: 0.0016 - val_ssim: 0.9434
# Epoch 51/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.4093e-04 - ssim: 0.9537
# Epoch 51: loss did not improve from 0.00071
# 252/252 [==============================] - 9s 36ms/step - loss: 7.4136e-04 - ssim: 0.9536 - val_loss: 0.0014 - val_ssim: 0.9348
# Epoch 52/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.1354e-04 - ssim: 0.9547
# Epoch 52: loss did not improve from 0.00071
# 252/252 [==============================] - 10s 39ms/step - loss: 7.1400e-04 - ssim: 0.9546 - val_loss: 0.0014 - val_ssim: 0.9298
# Epoch 53/100
# 251/252 [============================>.] - ETA: 0s - loss: 7.2476e-04 - ssim: 0.9543
# Epoch 53: loss did not improve from 0.00071
# 252/252 [==============================] - 9s 37ms/step - loss: 7.2586e-04 - ssim: 0.9543 - val_loss: 0.0016 - val_ssim: 0.9403
# Epoch 54/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.7654e-04 - ssim: 0.9579
# Epoch 54: loss improved from 0.00071 to 0.00068, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 6.7737e-04 - ssim: 0.9578 - val_loss: 0.0018 - val_ssim: 0.9426
# Epoch 55/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0497e-04 - ssim: 0.9561
# Epoch 55: loss did not improve from 0.00068
# 252/252 [==============================] - 10s 38ms/step - loss: 7.0497e-04 - ssim: 0.9561 - val_loss: 0.0013 - val_ssim: 0.9377
# Epoch 56/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0938e-04 - ssim: 0.9561
# Epoch 56: loss did not improve from 0.00068
# 252/252 [==============================] - 10s 42ms/step - loss: 7.0938e-04 - ssim: 0.9561 - val_loss: 0.0018 - val_ssim: 0.9419
# Epoch 57/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8460e-04 - ssim: 0.9572
# Epoch 57: loss did not improve from 0.00068
# 252/252 [==============================] - 11s 42ms/step - loss: 6.8460e-04 - ssim: 0.9572 - val_loss: 0.0013 - val_ssim: 0.9374
# Epoch 58/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8682e-04 - ssim: 0.9572
# Epoch 58: loss did not improve from 0.00068
# 252/252 [==============================] - 11s 42ms/step - loss: 6.8682e-04 - ssim: 0.9572 - val_loss: 0.0014 - val_ssim: 0.9380
# Epoch 59/100
# 252/252 [==============================] - ETA: 0s - loss: 6.7563e-04 - ssim: 0.9579
# Epoch 59: loss improved from 0.00068 to 0.00068, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 6.7563e-04 - ssim: 0.9579 - val_loss: 0.0014 - val_ssim: 0.9406
# Epoch 60/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8790e-04 - ssim: 0.9576
# Epoch 60: loss did not improve from 0.00068
# 252/252 [==============================] - 9s 37ms/step - loss: 6.8790e-04 - ssim: 0.9576 - val_loss: 0.0015 - val_ssim: 0.9419
# Epoch 61/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4262e-04 - ssim: 0.9596
# Epoch 61: loss improved from 0.00068 to 0.00064, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 6.4262e-04 - ssim: 0.9596 - val_loss: 0.0015 - val_ssim: 0.9394
# Epoch 62/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4509e-04 - ssim: 0.9601
# Epoch 62: loss did not improve from 0.00064
# 252/252 [==============================] - 10s 39ms/step - loss: 6.4509e-04 - ssim: 0.9601 - val_loss: 0.0013 - val_ssim: 0.9401
# Epoch 63/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5481e-04 - ssim: 0.9595
# Epoch 63: loss did not improve from 0.00064
# 252/252 [==============================] - 11s 42ms/step - loss: 6.5481e-04 - ssim: 0.9595 - val_loss: 0.0016 - val_ssim: 0.9385
# Epoch 64/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.5931e-04 - ssim: 0.9590
# Epoch 64: loss did not improve from 0.00064
# 252/252 [==============================] - 9s 36ms/step - loss: 6.5771e-04 - ssim: 0.9591 - val_loss: 0.0017 - val_ssim: 0.9271
# Epoch 65/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.4560e-04 - ssim: 0.9601
# Epoch 65: loss did not improve from 0.00064
# 252/252 [==============================] - 10s 39ms/step - loss: 6.4573e-04 - ssim: 0.9601 - val_loss: 0.0015 - val_ssim: 0.9385
# Epoch 66/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4769e-04 - ssim: 0.9601
# Epoch 66: loss did not improve from 0.00064
# 252/252 [==============================] - 10s 42ms/step - loss: 6.4769e-04 - ssim: 0.9601 - val_loss: 0.0015 - val_ssim: 0.9357
# Epoch 67/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.4232e-04 - ssim: 0.9602
# Epoch 67: loss did not improve from 0.00064
# 252/252 [==============================] - 10s 41ms/step - loss: 6.4265e-04 - ssim: 0.9602 - val_loss: 0.0016 - val_ssim: 0.9322
# Epoch 68/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.3341e-04 - ssim: 0.9607
# Epoch 68: loss improved from 0.00064 to 0.00063, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 45ms/step - loss: 6.3185e-04 - ssim: 0.9608 - val_loss: 0.0017 - val_ssim: 0.9351
# Epoch 69/100
# 252/252 [==============================] - ETA: 0s - loss: 6.0842e-04 - ssim: 0.9617
# Epoch 69: loss improved from 0.00063 to 0.00061, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 43ms/step - loss: 6.0842e-04 - ssim: 0.9617 - val_loss: 0.0018 - val_ssim: 0.9325
# Epoch 70/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.1429e-04 - ssim: 0.9617
# Epoch 70: loss did not improve from 0.00061
# 252/252 [==============================] - 10s 41ms/step - loss: 6.1467e-04 - ssim: 0.9616 - val_loss: 0.0020 - val_ssim: 0.9218
# Epoch 71/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.1087e-04 - ssim: 0.9617
# Epoch 71: loss did not improve from 0.00061
# 252/252 [==============================] - 11s 43ms/step - loss: 6.1110e-04 - ssim: 0.9617 - val_loss: 0.0017 - val_ssim: 0.9305
# Epoch 72/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2642e-04 - ssim: 0.9614
# Epoch 72: loss did not improve from 0.00061
# 252/252 [==============================] - 10s 42ms/step - loss: 6.2642e-04 - ssim: 0.9614 - val_loss: 0.0018 - val_ssim: 0.9308
# Epoch 73/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.9323e-04 - ssim: 0.9630
# Epoch 73: loss improved from 0.00061 to 0.00059, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.9344e-04 - ssim: 0.9630 - val_loss: 0.0017 - val_ssim: 0.9260
# Epoch 74/100
# 251/252 [============================>.] - ETA: 0s - loss: 6.3339e-04 - ssim: 0.9611
# Epoch 74: loss did not improve from 0.00059
# 252/252 [==============================] - 10s 38ms/step - loss: 6.3180e-04 - ssim: 0.9612 - val_loss: 0.0020 - val_ssim: 0.9300
# Epoch 75/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.8931e-04 - ssim: 0.9632
# Epoch 75: loss improved from 0.00059 to 0.00059, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 39ms/step - loss: 5.9044e-04 - ssim: 0.9632 - val_loss: 0.0020 - val_ssim: 0.9297
# Epoch 76/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.9549e-04 - ssim: 0.9625
# Epoch 76: loss did not improve from 0.00059
# 252/252 [==============================] - 9s 37ms/step - loss: 5.9582e-04 - ssim: 0.9625 - val_loss: 0.0019 - val_ssim: 0.9285
# Epoch 77/100
# 252/252 [==============================] - ETA: 0s - loss: 5.7325e-04 - ssim: 0.9637
# Epoch 77: loss improved from 0.00059 to 0.00057, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 45ms/step - loss: 5.7325e-04 - ssim: 0.9637 - val_loss: 0.0019 - val_ssim: 0.9237
# Epoch 78/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.6614e-04 - ssim: 0.9635
# Epoch 78: loss improved from 0.00057 to 0.00057, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.6724e-04 - ssim: 0.9634 - val_loss: 0.0017 - val_ssim: 0.9318
# Epoch 79/100
# 252/252 [==============================] - ETA: 0s - loss: 5.6455e-04 - ssim: 0.9639
# Epoch 79: loss improved from 0.00057 to 0.00056, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.6455e-04 - ssim: 0.9639 - val_loss: 0.0019 - val_ssim: 0.9285
# Epoch 80/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.6141e-04 - ssim: 0.9633
# Epoch 80: loss improved from 0.00056 to 0.00056, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 11s 44ms/step - loss: 5.6169e-04 - ssim: 0.9633 - val_loss: 0.0021 - val_ssim: 0.9300
# Epoch 81/100
# 252/252 [==============================] - ETA: 0s - loss: 5.5339e-04 - ssim: 0.9640
# Epoch 81: loss improved from 0.00056 to 0.00055, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.5339e-04 - ssim: 0.9640 - val_loss: 0.0021 - val_ssim: 0.9321
# Epoch 82/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.3243e-04 - ssim: 0.9652
# Epoch 82: loss improved from 0.00055 to 0.00053, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.3323e-04 - ssim: 0.9652 - val_loss: 0.0021 - val_ssim: 0.9256
# Epoch 83/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.4288e-04 - ssim: 0.9640
# Epoch 83: loss did not improve from 0.00053
# 252/252 [==============================] - 9s 36ms/step - loss: 5.4150e-04 - ssim: 0.9641 - val_loss: 0.0022 - val_ssim: 0.9205
# Epoch 84/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.1316e-04 - ssim: 0.9660
# Epoch 84: loss improved from 0.00053 to 0.00051, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 5.1350e-04 - ssim: 0.9660 - val_loss: 0.0024 - val_ssim: 0.9250
# Epoch 85/100
# 251/252 [============================>.] - ETA: 0s - loss: 5.1298e-04 - ssim: 0.9656
# Epoch 85: loss improved from 0.00051 to 0.00051, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 5.1301e-04 - ssim: 0.9655 - val_loss: 0.0025 - val_ssim: 0.9272
# Epoch 86/100
# 252/252 [==============================] - ETA: 0s - loss: 5.1454e-04 - ssim: 0.9654
# Epoch 86: loss did not improve from 0.00051
# 252/252 [==============================] - 9s 36ms/step - loss: 5.1454e-04 - ssim: 0.9654 - val_loss: 0.0024 - val_ssim: 0.9277
# Epoch 87/100
# 252/252 [==============================] - ETA: 0s - loss: 5.1298e-04 - ssim: 0.9654
# Epoch 87: loss improved from 0.00051 to 0.00051, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 40ms/step - loss: 5.1298e-04 - ssim: 0.9654 - val_loss: 0.0026 - val_ssim: 0.9304
# Epoch 88/100
# 252/252 [==============================] - ETA: 0s - loss: 5.1889e-04 - ssim: 0.9650
# Epoch 88: loss did not improve from 0.00051
# 252/252 [==============================] - 9s 36ms/step - loss: 5.1889e-04 - ssim: 0.9650 - val_loss: 0.0027 - val_ssim: 0.9217
# Epoch 89/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.9764e-04 - ssim: 0.9662
# Epoch 89: loss improved from 0.00051 to 0.00050, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 4.9786e-04 - ssim: 0.9662 - val_loss: 0.0026 - val_ssim: 0.9284
# Epoch 90/100
# 252/252 [==============================] - ETA: 0s - loss: 5.0374e-04 - ssim: 0.9660
# Epoch 90: loss did not improve from 0.00050
# 252/252 [==============================] - 11s 42ms/step - loss: 5.0374e-04 - ssim: 0.9660 - val_loss: 0.0029 - val_ssim: 0.9207
# Epoch 91/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.8843e-04 - ssim: 0.9667
# Epoch 91: loss improved from 0.00050 to 0.00049, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 9s 37ms/step - loss: 4.8856e-04 - ssim: 0.9667 - val_loss: 0.0024 - val_ssim: 0.9278
# Epoch 92/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.8762e-04 - ssim: 0.9664
# Epoch 92: loss improved from 0.00049 to 0.00049, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 9s 37ms/step - loss: 4.8764e-04 - ssim: 0.9664 - val_loss: 0.0028 - val_ssim: 0.9255
# Epoch 93/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.7144e-04 - ssim: 0.9672
# Epoch 93: loss improved from 0.00049 to 0.00047, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 38ms/step - loss: 4.7035e-04 - ssim: 0.9672 - val_loss: 0.0026 - val_ssim: 0.9273
# Epoch 94/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.7516e-04 - ssim: 0.9671
# Epoch 94: loss did not improve from 0.00047
# 252/252 [==============================] - 10s 38ms/step - loss: 4.7403e-04 - ssim: 0.9672 - val_loss: 0.0026 - val_ssim: 0.9254
# Epoch 95/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.7285e-04 - ssim: 0.9669
# Epoch 95: loss did not improve from 0.00047
# 252/252 [==============================] - 9s 36ms/step - loss: 4.7358e-04 - ssim: 0.9668 - val_loss: 0.0027 - val_ssim: 0.9232
# Epoch 96/100
# 252/252 [==============================] - ETA: 0s - loss: 4.7240e-04 - ssim: 0.9668
# Epoch 96: loss did not improve from 0.00047
# 252/252 [==============================] - 9s 36ms/step - loss: 4.7240e-04 - ssim: 0.9668 - val_loss: 0.0036 - val_ssim: 0.9187
# Epoch 97/100
# 252/252 [==============================] - ETA: 0s - loss: 4.5251e-04 - ssim: 0.9682
# Epoch 97: loss improved from 0.00047 to 0.00045, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 10s 39ms/step - loss: 4.5251e-04 - ssim: 0.9682 - val_loss: 0.0026 - val_ssim: 0.9207
# Epoch 98/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.6497e-04 - ssim: 0.9675
# Epoch 98: loss did not improve from 0.00045
# 252/252 [==============================] - 9s 36ms/step - loss: 4.6389e-04 - ssim: 0.9675 - val_loss: 0.0033 - val_ssim: 0.9174
# Epoch 99/100
# 251/252 [============================>.] - ETA: 0s - loss: 4.5417e-04 - ssim: 0.9680
# Epoch 99: loss did not improve from 0.00045
# 252/252 [==============================] - 9s 36ms/step - loss: 4.5430e-04 - ssim: 0.9680 - val_loss: 0.0032 - val_ssim: 0.9209
# Epoch 100/100
# 252/252 [==============================] - ETA: 0s - loss: 4.5485e-04 - ssim: 0.9679
# Epoch 100: loss did not improve from 0.00045
# 252/252 [==============================] - 10s 41ms/step - loss: 4.5485e-04 - ssim: 0.9679 - val_loss: 0.0031 - val_ssim: 0.9184

# %%
import pickle
with open('/kaggle/working/history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
print(type(history.history))
# Out:
# <class 'dict'>

# %%
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)
  
dependencies = {
    'ssim': ssim
}

# %%
model = keras.models.load_model('/kaggle/working/unet4.h5', custom_objects=dependencies)
#model = keras.models.load_model('/kaggle/input/unetmodel/unet4.h5', custom_objects=dependencies)

# %%
import pickle
with open('/kaggle/working/history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
import seaborn as sns
sns.set_style('dark')

# %%
plt.figure(figsize=(20,8))
loss = history['loss']
val_loss = history['val_loss']
length = len(loss)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
#plt.xticks(range(16), range(5,21))

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(history['ssim'])
plt.plot(history['val_ssim'])
plt.title('SSIM')
plt.ylabel('ssim')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
random_val_samples = val_generator1.__next__()
val_image_samples = random_val_samples[0]
val_mask_samples = random_val_samples[1]
predicted_masks = model.predict(val_image_samples)
# Out:
# 1/1 [==============================] - 1s 522ms/step

# %%
fig, axs = plt.subplots(1 , 3, figsize=(20,4))
axs[0].imshow(random_val_samples[0][0])
axs[0].set_title('Input Image')
axs[1].imshow(val_mask_samples[0])
axs[1].set_title('Actual Image')
axs[2].imshow(predicted_masks[0])
axs[2].set_title('Reconstructed Image')

print(predicted_masks[0].shape)
print(val_mask_samples[0].shape)
print(random_val_samples[0][0].shape)
#cv2.imwrite(op_path + '/train_img.jpg',t_image)
#cv2.imwrite(op_path + '/actual_img.jpg', a_image)
#cv2.imwrite(op_path + '/predicted.jpg', image)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)

# %%
p_image = (predicted_masks[0] * 255).astype(np.uint8)
a_image = (val_mask_samples[0] * 255).astype(np.uint8)
t_image = (random_val_samples[0][0] * 255).astype(np.uint8)

# %%
Ssim = []
n = 0
for i,m in val_generator:
    if n<100:
        img,mask = i,m
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        #print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        Ssim.append(acc)
        n=n+1
    else:
        break
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
print(mask[0].shape)
# Out:
# (256, 256, 3)

# %%
fig, ax = plt.subplots()

# Create a boxplot
ax.boxplot(Ssim)

# Set axis labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Boxplot of Data')

# Show the plot
plt.show()

# %%
Ssim = []
n = 0
for i,m in val_generator1:
    img,mask = i,m
    if n<5:
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        image1_array = mask[0]  # Get the NumPy array directly from the mask
        image2_array = pred[0]
        
        #image1_gray = mask[0].convert("L")
        #image2_gray = pred[0].convert("L")

# Convert the images to numpy arrays
        #image1_array = np.array(image1_gray)
        #image2_array = np.array(image2_gray)

# Compute the absolute difference between the two images
        diff_array = np.abs(image1_array - image2_array)
        #diff_array[0][3] = 1

# Find the maximum and minimum values in the difference matrix
        max_value = np.max(diff_array)
        min_value = np.min(diff_array)
        print(max_value)
        print(min_value)
        #max_value = 1
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))
        axes[0].imshow(mask[0])
        axes[0].set_title("Actual")
        axes[1].imshow(pred[0])
        axes[1].set_title("Predicted")
        im = axes[2].imshow(diff_array, cmap="Greens", vmax=max_value, vmin=min_value)
        axes[2].set_title("Difference")
        plt.colorbar(im, ax=axes[2])

        # Display the plot
        plt.show()
        n+=1
    else:
        break
# Out:
# 1/1 [==============================] - 0s 23ms/step
# SSIM: 0.9642016887664795
# 0.11800152
# 1.1920929e-07
# 1/1 [==============================] - 0s 34ms/step
# SSIM: 0.9282495975494385
# 0.1443802
# 1.3709068e-06
# 1/1 [==============================] - 0s 24ms/step
# SSIM: 0.9324264526367188
# 0.12217215
# 3.2782555e-07
# 1/1 [==============================] - 0s 24ms/step
# SSIM: 0.9645180702209473
# 0.12281132
# 1.1920929e-07
# 1/1 [==============================] - 0s 23ms/step
# SSIM: 0.9317488074302673
# 0.13212842
# 1.1920929e-07
