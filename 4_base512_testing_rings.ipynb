# %% [markdown]
# #Imports and path setup

# %%
# imports
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np
import os
#from google.colab.patches import cv_imshow
import cv2
import imgaug 
import imgaug as ia
import imgaug.augmenters as iaa
from sklearn.model_selection import train_test_split
import random
import shutil
from keras.layers import UpSampling2D

# %%
# define paths
bmp_path = '/kaggle/input'
op_path = '/kaggle/working'
circle_path = bmp_path + '/circles_new'
bamboo_path = bmp_path + '/bamboo'
image_path = bmp_path + '/minorproject'
train_image_path = image_path + '/train_images_latest'
true_image_path = image_path + '/true_images_new'
raw_masks_path = f"{bmp_path}/raw_masks_new/"
masks_path = f"{bmp_path}/masks_new/"
test_path=bmp_path + '/tesing1/'

# %%
X = np.array(list(map(lambda a : image_path + '/' + a, os.listdir(image_path))))
y = np.array(list(map(lambda a : true_image_path + '/' + a, os.listdir(true_image_path))))

# %%
print(X.shape)
# Out:
# (2,)

# %%
print(y.shape)
# Out:
# (2525,)

# %% [markdown]
# ## Image generator

# %%
# function for normalization
def normalize(input_image):
  input_image = tf.cast(input_image, tf.float32) / 255.0
  # input_mask = tf.cast(input_mask, tf.float32) / 255.0
  return input_image

# %%
# generate image dataset
img_dim = 256
batch_sz = 1
image_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2)
mask_datagen = ImageDataGenerator(rescale=1./255,validation_split=0.2)
#print(image_datagen.shape)

train_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode=,
        batch_size = batch_sz,
        seed=42,
        subset='training')
    
train_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        batch_size = batch_sz,
        seed=42,
        subset='training')

val_image_generator = image_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['train_images_latest'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')
    
val_mask_generator = mask_datagen.flow_from_directory(
        image_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images_new'],
        # color_mode='grayscale',
        batch_size = batch_sz,
        seed=42,
        subset='validation')


train_generator = zip(train_image_generator, train_mask_generator)
val_generator = zip(val_image_generator, val_mask_generator)
# Out:
# Found 2020 images belonging to 1 classes.
# Found 2020 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.
# Found 505 images belonging to 1 classes.

# %%
training_samples_size = train_image_generator.samples
val_samples_size = val_image_generator.samples
print(training_samples_size)
print(val_samples_size)
# Out:
# 2020
# 505

# %% [markdown]
# ##U-Net

# %%
# batch/buffer sizes for NN
BATCH_SIZE = 8
BUFFER_SIZE = 1000
# train_batches = train_dataset.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()
# train_batches = train_batches.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
# validation_batches = test_dataset.take(3000).batch(BATCH_SIZE)
# test_batches = test_dataset.skip(3000).take(669).batch(BATCH_SIZE)

# %%
# custom convolution
def conv_block(input, num_filters):
  # First Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(input)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  # Second Conv2D layer
  x = layers.Conv2D(num_filters, 3, padding="same")(x)
  #x = layers.BatchNormalization()(x)
  x = layers.Activation("relu")(x)
  x = layers.BatchNormalization()(x)
  
  return x

# %%
# custom encoder
def encoder_block(input, num_filters):
  x = conv_block(input, num_filters)
  p = layers.MaxPool2D(2)(x)

  return x, p

# %%
# custom decoder
def decoder_block(input, skip_features, num_filters):
  #x = layers.Conv2DTranspose(num_filters, 3, strides=2, padding='same')(input)
  #x = UpSampling2D(size=(2, 2), data_format="channels_last", interpolation="bilinear")(input)
  x = UpSampling2D(size=(2, 2), interpolation="gaussian")(input)
  x = layers.Concatenate()([skip_features, x])
  x = layers.Dropout(0.3)(x)
  x = conv_block(x, num_filters)

  return x

# %%
# function to build unet
def build_unet_model(input_shape):
  inputs = layers.Input(shape=input_shape)

  # Encoders
  #s1, p1 = encoder_block(inputs,8)
  #s1, p1= encoder_block(inputs,16)
  s1, p1= encoder_block(inputs,32)
  s2, p2= encoder_block(p1,64)
  s3, p3= encoder_block(p2,128)
  s4, p4= encoder_block(p3, 256)
  #s6, p6= encoder_block(p5, 512)
  # s5, p6 = encoder_block(p4, 1024)

  # Base
  b = conv_block(p4, 512)

  # Decoders
  # d = decoder_block(b, s5, 1024)
  #d1 = decoder_block(b, s6, 512)
  d1 = decoder_block(b, s4, 256)
  d2 = decoder_block(d1,s3,128)
  d3 = decoder_block(d2,s2,64)
  d4 = decoder_block(d3, s1, 32)
  #d6 = decoder_block(d5, s1, 16)
  #d6 = decoder_block(d5, s1, 8)
  

  # Output
  outputs = layers.Conv2D(3, 3, padding='same', activation='relu')(d4)

  # UNet model 
  unet_model = keras.Model(inputs, outputs, name='U-Net')

  return unet_model

# %%
#SSIM metrics
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)

def ape(y_true, y_pred):
  return tf.keras.losses.MeanAbsolutePercentageError(y_true, y_pred)

# %%
# build model
unet_model = build_unet_model((img_dim, img_dim, 3))

# %%
# unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
#                   loss="MSE",
#                   metrics=[ssim, tf.keras.metrics.MeanAbsolutePercentageError()])
unet_model.compile(optimizer=tf.keras.optimizers.Adam(),
                  loss="MSE",
                  metrics=[ssim])

# %%
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  conv2d_58 (Conv2D)             (None, 256, 256, 32  896         ['input_5[0][0]']
#                                 )
#
#  activation_56 (Activation)     (None, 256, 256, 32  0           ['conv2d_58[0][0]']
#                                 )
#
#  batch_normalization_56 (BatchN  (None, 256, 256, 32  128        ['activation_56[0][0]']
#  ormalization)                  )
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_56[0][0]']
#                                 )
#
#  activation_57 (Activation)     (None, 256, 256, 32  0           ['conv2d_59[0][0]']
#                                 )
#
#  batch_normalization_57 (BatchN  (None, 256, 256, 32  128        ['activation_57[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_16 (MaxPooling2D  (None, 128, 128, 32  0          ['batch_normalization_57[0][0]']
#  )                              )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 64  18496       ['max_pooling2d_16[0][0]']
#                                 )
#
#  activation_58 (Activation)     (None, 128, 128, 64  0           ['conv2d_60[0][0]']
#                                 )
#
#  batch_normalization_58 (BatchN  (None, 128, 128, 64  256        ['activation_58[0][0]']
#  ormalization)                  )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_58[0][0]']
#                                 )
#
#  activation_59 (Activation)     (None, 128, 128, 64  0           ['conv2d_61[0][0]']
#                                 )
#
#  batch_normalization_59 (BatchN  (None, 128, 128, 64  256        ['activation_59[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_17 (MaxPooling2D  (None, 64, 64, 64)  0           ['batch_normalization_59[0][0]']
#  )
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 128)  73856       ['max_pooling2d_17[0][0]']
#
#  activation_60 (Activation)     (None, 64, 64, 128)  0           ['conv2d_62[0][0]']
#
#  batch_normalization_60 (BatchN  (None, 64, 64, 128)  512        ['activation_60[0][0]']
#  ormalization)
#
#  conv2d_63 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_60[0][0]']
#
#  activation_61 (Activation)     (None, 64, 64, 128)  0           ['conv2d_63[0][0]']
#
#  batch_normalization_61 (BatchN  (None, 64, 64, 128)  512        ['activation_61[0][0]']
#  ormalization)
#
#  max_pooling2d_18 (MaxPooling2D  (None, 32, 32, 128)  0          ['batch_normalization_61[0][0]']
#  )
#
#  conv2d_64 (Conv2D)             (None, 32, 32, 256)  295168      ['max_pooling2d_18[0][0]']
#
#  activation_62 (Activation)     (None, 32, 32, 256)  0           ['conv2d_64[0][0]']
#
#  batch_normalization_62 (BatchN  (None, 32, 32, 256)  1024       ['activation_62[0][0]']
#  ormalization)
#
#  conv2d_65 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_62[0][0]']
#
#  activation_63 (Activation)     (None, 32, 32, 256)  0           ['conv2d_65[0][0]']
#
#  batch_normalization_63 (BatchN  (None, 32, 32, 256)  1024       ['activation_63[0][0]']
#  ormalization)
#
#  max_pooling2d_19 (MaxPooling2D  (None, 16, 16, 256)  0          ['batch_normalization_63[0][0]']
#  )
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 512)  1180160     ['max_pooling2d_19[0][0]']
#
#  activation_64 (Activation)     (None, 16, 16, 512)  0           ['conv2d_66[0][0]']
#
#  batch_normalization_64 (BatchN  (None, 16, 16, 512)  2048       ['activation_64[0][0]']
#  ormalization)
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 512)  2359808     ['batch_normalization_64[0][0]']
#
#  activation_65 (Activation)     (None, 16, 16, 512)  0           ['conv2d_67[0][0]']
#
#  batch_normalization_65 (BatchN  (None, 16, 16, 512)  2048       ['activation_65[0][0]']
#  ormalization)
#
#  up_sampling2d_9 (UpSampling2D)  (None, 32, 32, 512)  0          ['batch_normalization_65[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 32, 32, 768)  0           ['batch_normalization_63[0][0]',
#                                                                   'up_sampling2d_9[0][0]']
#
#  dropout_8 (Dropout)            (None, 32, 32, 768)  0           ['concatenate_8[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 256)  1769728     ['dropout_8[0][0]']
#
#  activation_66 (Activation)     (None, 32, 32, 256)  0           ['conv2d_68[0][0]']
#
#  batch_normalization_66 (BatchN  (None, 32, 32, 256)  1024       ['activation_66[0][0]']
#  ormalization)
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 256)  590080      ['batch_normalization_66[0][0]']
#
#  activation_67 (Activation)     (None, 32, 32, 256)  0           ['conv2d_69[0][0]']
#
#  batch_normalization_67 (BatchN  (None, 32, 32, 256)  1024       ['activation_67[0][0]']
#  ormalization)
#
#  up_sampling2d_10 (UpSampling2D  (None, 64, 64, 256)  0          ['batch_normalization_67[0][0]']
#  )
#
#  concatenate_9 (Concatenate)    (None, 64, 64, 384)  0           ['batch_normalization_61[0][0]',
#                                                                   'up_sampling2d_10[0][0]']
#
#  dropout_9 (Dropout)            (None, 64, 64, 384)  0           ['concatenate_9[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 64, 64, 128)  442496      ['dropout_9[0][0]']
#
#  activation_68 (Activation)     (None, 64, 64, 128)  0           ['conv2d_70[0][0]']
#
#  batch_normalization_68 (BatchN  (None, 64, 64, 128)  512        ['activation_68[0][0]']
#  ormalization)
#
#  conv2d_71 (Conv2D)             (None, 64, 64, 128)  147584      ['batch_normalization_68[0][0]']
#
#  activation_69 (Activation)     (None, 64, 64, 128)  0           ['conv2d_71[0][0]']
#
#  batch_normalization_69 (BatchN  (None, 64, 64, 128)  512        ['activation_69[0][0]']
#  ormalization)
#
#  up_sampling2d_11 (UpSampling2D  (None, 128, 128, 12  0          ['batch_normalization_69[0][0]']
#  )                              8)
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 19  0           ['batch_normalization_59[0][0]',
#                                 2)                                'up_sampling2d_11[0][0]']
#
#  dropout_10 (Dropout)           (None, 128, 128, 19  0           ['concatenate_10[0][0]']
#                                 2)
#
#  conv2d_72 (Conv2D)             (None, 128, 128, 64  110656      ['dropout_10[0][0]']
#                                 )
#
#  activation_70 (Activation)     (None, 128, 128, 64  0           ['conv2d_72[0][0]']
#                                 )
#
#  batch_normalization_70 (BatchN  (None, 128, 128, 64  256        ['activation_70[0][0]']
#  ormalization)                  )
#
#  conv2d_73 (Conv2D)             (None, 128, 128, 64  36928       ['batch_normalization_70[0][0]']
#                                 )
#
#  activation_71 (Activation)     (None, 128, 128, 64  0           ['conv2d_73[0][0]']
#                                 )
#
#  batch_normalization_71 (BatchN  (None, 128, 128, 64  256        ['activation_71[0][0]']
#  ormalization)                  )
#
#  up_sampling2d_12 (UpSampling2D  (None, 256, 256, 64  0          ['batch_normalization_71[0][0]']
#  )                              )
#
#  concatenate_11 (Concatenate)   (None, 256, 256, 96  0           ['batch_normalization_57[0][0]',
#                                 )                                 'up_sampling2d_12[0][0]']
#
#  dropout_11 (Dropout)           (None, 256, 256, 96  0           ['concatenate_11[0][0]']
#                                 )
#
#  conv2d_74 (Conv2D)             (None, 256, 256, 32  27680       ['dropout_11[0][0]']
#                                 )
#
#  activation_72 (Activation)     (None, 256, 256, 32  0           ['conv2d_74[0][0]']
#                                 )
#
#  batch_normalization_72 (BatchN  (None, 256, 256, 32  128        ['activation_72[0][0]']
#  ormalization)                  )
#
#  conv2d_75 (Conv2D)             (None, 256, 256, 32  9248        ['batch_normalization_72[0][0]']
#                                 )
#
#  activation_73 (Activation)     (None, 256, 256, 32  0           ['conv2d_75[0][0]']
#                                 )
#
#  batch_normalization_73 (BatchN  (None, 256, 256, 32  128        ['activation_73[0][0]']
#  ormalization)                  )
#
#  conv2d_76 (Conv2D)             (None, 256, 256, 3)  867         ['batch_normalization_73[0][0]']
#
# ==================================================================================================
# Total params: 7,859,267
# Trainable params: 7,853,379
# Non-trainable params: 5,888
# __________________________________________________________________________________________________

# %%
# save model
model_path = op_path + "/unet4.h5"
checkpoint = keras.callbacks.ModelCheckpoint(model_path,
                             monitor="loss",
                             mode="min",
                             save_best_only = True,
                             verbose=1)

# earlystop = keras.callbacks.EarlyStopping(monitor = 'loss', 
#                           min_delta = 0, 
#                           patience = 5,
#                           verbose = 1,
#                           restore_best_weights = True)

# %%
history = unet_model.fit(train_generator,
                    steps_per_epoch=training_samples_size//BATCH_SIZE,
                    validation_data=val_generator,
                    validation_steps=val_samples_size//BATCH_SIZE,
                    epochs=100, callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 2023-04-26 14:39:55.307841: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout_8/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 252/252 [==============================] - ETA: 0s - loss: 0.0258 - ssim: 0.6966
# Epoch 1: loss improved from inf to 0.02581, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 48s 145ms/step - loss: 0.0258 - ssim: 0.6966 - val_loss: 0.0289 - val_ssim: 0.2980
# Epoch 2/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0029 - ssim: 0.8458
# Epoch 2: loss improved from 0.02581 to 0.00292, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0029 - ssim: 0.8458 - val_loss: 0.0056 - val_ssim: 0.8585
# Epoch 3/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0452 - ssim: 0.7503
# Epoch 3: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 141ms/step - loss: 0.0452 - ssim: 0.7503 - val_loss: 0.1693 - val_ssim: 0.3465
# Epoch 4/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0082 - ssim: 0.8607
# Epoch 4: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0082 - ssim: 0.8607 - val_loss: 0.0222 - val_ssim: 0.8572
# Epoch 5/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0061 - ssim: 0.8813
# Epoch 5: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0061 - ssim: 0.8813 - val_loss: 0.1730 - val_ssim: 0.3758
# Epoch 6/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0050 - ssim: 0.8909
# Epoch 6: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0050 - ssim: 0.8909 - val_loss: 0.0148 - val_ssim: 0.9290
# Epoch 7/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0049 - ssim: 0.8973
# Epoch 7: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0049 - ssim: 0.8973 - val_loss: 0.2532 - val_ssim: 0.1466
# Epoch 8/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0035 - ssim: 0.9065
# Epoch 8: loss did not improve from 0.00292
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0035 - ssim: 0.9065 - val_loss: 0.0036 - val_ssim: 0.9430
# Epoch 9/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0028 - ssim: 0.9139
# Epoch 9: loss improved from 0.00292 to 0.00278, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0028 - ssim: 0.9139 - val_loss: 0.0038 - val_ssim: 0.9414
# Epoch 10/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0025 - ssim: 0.9207
# Epoch 10: loss improved from 0.00278 to 0.00246, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 0.0025 - ssim: 0.9207 - val_loss: 0.0029 - val_ssim: 0.9472
# Epoch 11/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0023 - ssim: 0.9213
# Epoch 11: loss improved from 0.00246 to 0.00231, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0023 - ssim: 0.9213 - val_loss: 0.0042 - val_ssim: 0.9332
# Epoch 12/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0022 - ssim: 0.9234
# Epoch 12: loss improved from 0.00231 to 0.00222, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0022 - ssim: 0.9234 - val_loss: 0.0022 - val_ssim: 0.9451
# Epoch 13/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0021 - ssim: 0.9258
# Epoch 13: loss improved from 0.00222 to 0.00213, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 143ms/step - loss: 0.0021 - ssim: 0.9258 - val_loss: 0.0061 - val_ssim: 0.9333
# Epoch 14/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0021 - ssim: 0.9271
# Epoch 14: loss improved from 0.00213 to 0.00209, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 141ms/step - loss: 0.0021 - ssim: 0.9271 - val_loss: 0.0028 - val_ssim: 0.9412
# Epoch 15/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0022 - ssim: 0.9270
# Epoch 15: loss did not improve from 0.00209
# 252/252 [==============================] - 35s 141ms/step - loss: 0.0022 - ssim: 0.9270 - val_loss: 0.0025 - val_ssim: 0.9442
# Epoch 16/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0015 - ssim: 0.9282
# Epoch 16: loss improved from 0.00209 to 0.00151, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 138ms/step - loss: 0.0015 - ssim: 0.9282 - val_loss: 0.0042 - val_ssim: 0.9350
# Epoch 17/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0013 - ssim: 0.9274
# Epoch 17: loss improved from 0.00151 to 0.00127, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0013 - ssim: 0.9274 - val_loss: 0.0014 - val_ssim: 0.9419
# Epoch 18/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9309
# Epoch 18: loss improved from 0.00127 to 0.00120, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 0.0012 - ssim: 0.9309 - val_loss: 0.0012 - val_ssim: 0.9445
# Epoch 19/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9312
# Epoch 19: loss improved from 0.00120 to 0.00119, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0012 - ssim: 0.9312 - val_loss: 0.0013 - val_ssim: 0.9454
# Epoch 20/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9343
# Epoch 20: loss improved from 0.00119 to 0.00113, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0011 - ssim: 0.9343 - val_loss: 0.0013 - val_ssim: 0.9465
# Epoch 21/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0013 - ssim: 0.9325
# Epoch 21: loss did not improve from 0.00113
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0013 - ssim: 0.9325 - val_loss: 0.0016 - val_ssim: 0.9453
# Epoch 22/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9353
# Epoch 22: loss did not improve from 0.00113
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0012 - ssim: 0.9353 - val_loss: 0.0468 - val_ssim: 0.7197
# Epoch 23/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9327
# Epoch 23: loss did not improve from 0.00113
# 252/252 [==============================] - 34s 136ms/step - loss: 0.0012 - ssim: 0.9327 - val_loss: 0.0015 - val_ssim: 0.9437
# Epoch 24/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9347
# Epoch 24: loss improved from 0.00113 to 0.00112, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 0.0011 - ssim: 0.9347 - val_loss: 0.0013 - val_ssim: 0.9441
# Epoch 25/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9364
# Epoch 25: loss improved from 0.00112 to 0.00109, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 141ms/step - loss: 0.0011 - ssim: 0.9364 - val_loss: 0.0022 - val_ssim: 0.9264
# Epoch 26/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0015 - ssim: 0.9308
# Epoch 26: loss did not improve from 0.00109
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0015 - ssim: 0.9308 - val_loss: 0.0376 - val_ssim: 0.8011
# Epoch 27/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9323
# Epoch 27: loss did not improve from 0.00109
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0012 - ssim: 0.9323 - val_loss: 0.0015 - val_ssim: 0.9429
# Epoch 28/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9334
# Epoch 28: loss did not improve from 0.00109
# 252/252 [==============================] - 35s 138ms/step - loss: 0.0011 - ssim: 0.9334 - val_loss: 0.0013 - val_ssim: 0.9408
# Epoch 29/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9341
# Epoch 29: loss did not improve from 0.00109
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0011 - ssim: 0.9341 - val_loss: 0.0016 - val_ssim: 0.9389
# Epoch 30/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9364
# Epoch 30: loss did not improve from 0.00109
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0011 - ssim: 0.9364 - val_loss: 0.0011 - val_ssim: 0.9382
# Epoch 31/100
# 252/252 [==============================] - ETA: 0s - loss: 9.8080e-04 - ssim: 0.9395
# Epoch 31: loss improved from 0.00109 to 0.00098, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 9.8080e-04 - ssim: 0.9395 - val_loss: 0.0012 - val_ssim: 0.9374
# Epoch 32/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9379
# Epoch 32: loss did not improve from 0.00098
# 252/252 [==============================] - 35s 141ms/step - loss: 0.0011 - ssim: 0.9379 - val_loss: 0.0014 - val_ssim: 0.9372
# Epoch 33/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9385
# Epoch 33: loss did not improve from 0.00098
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0011 - ssim: 0.9385 - val_loss: 0.0011 - val_ssim: 0.9391
# Epoch 34/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9406
# Epoch 34: loss did not improve from 0.00098
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0010 - ssim: 0.9406 - val_loss: 0.0013 - val_ssim: 0.9349
# Epoch 35/100
# 252/252 [==============================] - ETA: 0s - loss: 9.3241e-04 - ssim: 0.9431
# Epoch 35: loss improved from 0.00098 to 0.00093, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 9.3241e-04 - ssim: 0.9431 - val_loss: 0.0013 - val_ssim: 0.9360
# Epoch 36/100
# 252/252 [==============================] - ETA: 0s - loss: 9.6094e-04 - ssim: 0.9426
# Epoch 36: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 9.6094e-04 - ssim: 0.9426 - val_loss: 0.0016 - val_ssim: 0.9312
# Epoch 37/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0034 - ssim: 0.9162
# Epoch 37: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0034 - ssim: 0.9162 - val_loss: 0.1083 - val_ssim: 0.5419
# Epoch 38/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0017 - ssim: 0.9155
# Epoch 38: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0017 - ssim: 0.9155 - val_loss: 0.0017 - val_ssim: 0.9366
# Epoch 39/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9257
# Epoch 39: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 137ms/step - loss: 0.0012 - ssim: 0.9257 - val_loss: 0.0015 - val_ssim: 0.9361
# Epoch 40/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0013 - ssim: 0.9271
# Epoch 40: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0013 - ssim: 0.9271 - val_loss: 0.0079 - val_ssim: 0.8452
# Epoch 41/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0015 - ssim: 0.9289
# Epoch 41: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0015 - ssim: 0.9289 - val_loss: 0.0020 - val_ssim: 0.9430
# Epoch 42/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0015 - ssim: 0.9289
# Epoch 42: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0015 - ssim: 0.9289 - val_loss: 0.0481 - val_ssim: 0.7676
# Epoch 43/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9329
# Epoch 43: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0012 - ssim: 0.9329 - val_loss: 0.0107 - val_ssim: 0.9070
# Epoch 44/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9332
# Epoch 44: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0012 - ssim: 0.9332 - val_loss: 0.0038 - val_ssim: 0.9413
# Epoch 45/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9337
# Epoch 45: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0011 - ssim: 0.9337 - val_loss: 0.0019 - val_ssim: 0.9393
# Epoch 46/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0010 - ssim: 0.9353
# Epoch 46: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 140ms/step - loss: 0.0010 - ssim: 0.9353 - val_loss: 0.0026 - val_ssim: 0.9359
# Epoch 47/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0012 - ssim: 0.9308
# Epoch 47: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 139ms/step - loss: 0.0012 - ssim: 0.9308 - val_loss: 0.0019 - val_ssim: 0.9341
# Epoch 48/100
# 252/252 [==============================] - ETA: 0s - loss: 9.9764e-04 - ssim: 0.9351
# Epoch 48: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 9.9764e-04 - ssim: 0.9351 - val_loss: 0.0021 - val_ssim: 0.9349
# Epoch 49/100
# 252/252 [==============================] - ETA: 0s - loss: 9.5215e-04 - ssim: 0.9386
# Epoch 49: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 137ms/step - loss: 9.5215e-04 - ssim: 0.9386 - val_loss: 0.0090 - val_ssim: 0.9128
# Epoch 50/100
# 252/252 [==============================] - ETA: 0s - loss: 9.5028e-04 - ssim: 0.9413
# Epoch 50: loss did not improve from 0.00093
# 252/252 [==============================] - 35s 140ms/step - loss: 9.5028e-04 - ssim: 0.9413 - val_loss: 0.0027 - val_ssim: 0.9316
# Epoch 51/100
# 252/252 [==============================] - ETA: 0s - loss: 0.0011 - ssim: 0.9397
# Epoch 51: loss did not improve from 0.00093
# 252/252 [==============================] - 34s 137ms/step - loss: 0.0011 - ssim: 0.9397 - val_loss: 0.0024 - val_ssim: 0.9410
# Epoch 52/100
# 252/252 [==============================] - ETA: 0s - loss: 8.7695e-04 - ssim: 0.9428
# Epoch 52: loss improved from 0.00093 to 0.00088, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 8.7695e-04 - ssim: 0.9428 - val_loss: 0.0033 - val_ssim: 0.9349
# Epoch 53/100
# 252/252 [==============================] - ETA: 0s - loss: 8.5357e-04 - ssim: 0.9423
# Epoch 53: loss improved from 0.00088 to 0.00085, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 8.5357e-04 - ssim: 0.9423 - val_loss: 0.0032 - val_ssim: 0.9359
# Epoch 54/100
# 252/252 [==============================] - ETA: 0s - loss: 7.9459e-04 - ssim: 0.9455
# Epoch 54: loss improved from 0.00085 to 0.00079, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 7.9459e-04 - ssim: 0.9455 - val_loss: 0.0030 - val_ssim: 0.9305
# Epoch 55/100
# 252/252 [==============================] - ETA: 0s - loss: 8.3253e-04 - ssim: 0.9439
# Epoch 55: loss did not improve from 0.00079
# 252/252 [==============================] - 34s 137ms/step - loss: 8.3253e-04 - ssim: 0.9439 - val_loss: 0.0048 - val_ssim: 0.9173
# Epoch 56/100
# 252/252 [==============================] - ETA: 0s - loss: 8.1347e-04 - ssim: 0.9442
# Epoch 56: loss did not improve from 0.00079
# 252/252 [==============================] - 36s 142ms/step - loss: 8.1347e-04 - ssim: 0.9442 - val_loss: 0.0060 - val_ssim: 0.9032
# Epoch 57/100
# 252/252 [==============================] - ETA: 0s - loss: 8.3668e-04 - ssim: 0.9430
# Epoch 57: loss did not improve from 0.00079
# 252/252 [==============================] - 35s 141ms/step - loss: 8.3668e-04 - ssim: 0.9430 - val_loss: 0.0061 - val_ssim: 0.9101
# Epoch 58/100
# 252/252 [==============================] - ETA: 0s - loss: 8.1166e-04 - ssim: 0.9431
# Epoch 58: loss did not improve from 0.00079
# 252/252 [==============================] - 34s 137ms/step - loss: 8.1166e-04 - ssim: 0.9431 - val_loss: 0.0042 - val_ssim: 0.9180
# Epoch 59/100
# 252/252 [==============================] - ETA: 0s - loss: 8.2775e-04 - ssim: 0.9441
# Epoch 59: loss did not improve from 0.00079
# 252/252 [==============================] - 35s 140ms/step - loss: 8.2775e-04 - ssim: 0.9441 - val_loss: 0.0045 - val_ssim: 0.9039
# Epoch 60/100
# 252/252 [==============================] - ETA: 0s - loss: 8.0965e-04 - ssim: 0.9445
# Epoch 60: loss did not improve from 0.00079
# 252/252 [==============================] - 35s 141ms/step - loss: 8.0965e-04 - ssim: 0.9445 - val_loss: 0.0046 - val_ssim: 0.8995
# Epoch 61/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6443e-04 - ssim: 0.9461
# Epoch 61: loss improved from 0.00079 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 7.6443e-04 - ssim: 0.9461 - val_loss: 0.0053 - val_ssim: 0.8979
# Epoch 62/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6352e-04 - ssim: 0.9471
# Epoch 62: loss improved from 0.00076 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 7.6352e-04 - ssim: 0.9471 - val_loss: 0.0048 - val_ssim: 0.9064
# Epoch 63/100
# 252/252 [==============================] - ETA: 0s - loss: 7.9254e-04 - ssim: 0.9458
# Epoch 63: loss did not improve from 0.00076
# 252/252 [==============================] - 35s 137ms/step - loss: 7.9254e-04 - ssim: 0.9458 - val_loss: 0.0060 - val_ssim: 0.9053
# Epoch 64/100
# 252/252 [==============================] - ETA: 0s - loss: 7.8831e-04 - ssim: 0.9448
# Epoch 64: loss did not improve from 0.00076
# 252/252 [==============================] - 34s 137ms/step - loss: 7.8831e-04 - ssim: 0.9448 - val_loss: 0.0055 - val_ssim: 0.9149
# Epoch 65/100
# 252/252 [==============================] - ETA: 0s - loss: 7.7201e-04 - ssim: 0.9462
# Epoch 65: loss did not improve from 0.00076
# 252/252 [==============================] - 35s 140ms/step - loss: 7.7201e-04 - ssim: 0.9462 - val_loss: 0.0050 - val_ssim: 0.9130
# Epoch 66/100
# 252/252 [==============================] - ETA: 0s - loss: 7.5839e-04 - ssim: 0.9472
# Epoch 66: loss improved from 0.00076 to 0.00076, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 7.5839e-04 - ssim: 0.9472 - val_loss: 0.0057 - val_ssim: 0.9072
# Epoch 67/100
# 252/252 [==============================] - ETA: 0s - loss: 7.6314e-04 - ssim: 0.9469
# Epoch 67: loss did not improve from 0.00076
# 252/252 [==============================] - 35s 140ms/step - loss: 7.6314e-04 - ssim: 0.9469 - val_loss: 0.0064 - val_ssim: 0.9056
# Epoch 68/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4953e-04 - ssim: 0.9481
# Epoch 68: loss improved from 0.00076 to 0.00075, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 7.4953e-04 - ssim: 0.9481 - val_loss: 0.0067 - val_ssim: 0.9028
# Epoch 69/100
# 252/252 [==============================] - ETA: 0s - loss: 7.2975e-04 - ssim: 0.9492
# Epoch 69: loss improved from 0.00075 to 0.00073, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 141ms/step - loss: 7.2975e-04 - ssim: 0.9492 - val_loss: 0.0063 - val_ssim: 0.9020
# Epoch 70/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4158e-04 - ssim: 0.9493
# Epoch 70: loss did not improve from 0.00073
# 252/252 [==============================] - 35s 137ms/step - loss: 7.4158e-04 - ssim: 0.9493 - val_loss: 0.0056 - val_ssim: 0.9047
# Epoch 71/100
# 252/252 [==============================] - ETA: 0s - loss: 8.2599e-04 - ssim: 0.9454
# Epoch 71: loss did not improve from 0.00073
# 252/252 [==============================] - 34s 137ms/step - loss: 8.2599e-04 - ssim: 0.9454 - val_loss: 0.0048 - val_ssim: 0.9129
# Epoch 72/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4673e-04 - ssim: 0.9472
# Epoch 72: loss did not improve from 0.00073
# 252/252 [==============================] - 35s 137ms/step - loss: 7.4673e-04 - ssim: 0.9472 - val_loss: 0.0052 - val_ssim: 0.9067
# Epoch 73/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0435e-04 - ssim: 0.9499
# Epoch 73: loss improved from 0.00073 to 0.00070, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 138ms/step - loss: 7.0435e-04 - ssim: 0.9499 - val_loss: 0.0054 - val_ssim: 0.9039
# Epoch 74/100
# 252/252 [==============================] - ETA: 0s - loss: 7.4734e-04 - ssim: 0.9483
# Epoch 74: loss did not improve from 0.00070
# 252/252 [==============================] - 35s 140ms/step - loss: 7.4734e-04 - ssim: 0.9483 - val_loss: 0.0067 - val_ssim: 0.9072
# Epoch 75/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0198e-04 - ssim: 0.9507
# Epoch 75: loss improved from 0.00070 to 0.00070, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 7.0198e-04 - ssim: 0.9507 - val_loss: 0.0062 - val_ssim: 0.8961
# Epoch 76/100
# 252/252 [==============================] - ETA: 0s - loss: 7.1064e-04 - ssim: 0.9503
# Epoch 76: loss did not improve from 0.00070
# 252/252 [==============================] - 34s 137ms/step - loss: 7.1064e-04 - ssim: 0.9503 - val_loss: 0.0069 - val_ssim: 0.8995
# Epoch 77/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8960e-04 - ssim: 0.9517
# Epoch 77: loss improved from 0.00070 to 0.00069, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 6.8960e-04 - ssim: 0.9517 - val_loss: 0.0062 - val_ssim: 0.9060
# Epoch 78/100
# 252/252 [==============================] - ETA: 0s - loss: 6.9206e-04 - ssim: 0.9510
# Epoch 78: loss did not improve from 0.00069
# 252/252 [==============================] - 34s 137ms/step - loss: 6.9206e-04 - ssim: 0.9510 - val_loss: 0.0060 - val_ssim: 0.8967
# Epoch 79/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8819e-04 - ssim: 0.9517
# Epoch 79: loss improved from 0.00069 to 0.00069, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 6.8819e-04 - ssim: 0.9517 - val_loss: 0.0056 - val_ssim: 0.8981
# Epoch 80/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0382e-04 - ssim: 0.9508
# Epoch 80: loss did not improve from 0.00069
# 252/252 [==============================] - 34s 137ms/step - loss: 7.0382e-04 - ssim: 0.9508 - val_loss: 0.0055 - val_ssim: 0.8981
# Epoch 81/100
# 252/252 [==============================] - ETA: 0s - loss: 6.9506e-04 - ssim: 0.9519
# Epoch 81: loss did not improve from 0.00069
# 252/252 [==============================] - 34s 137ms/step - loss: 6.9506e-04 - ssim: 0.9519 - val_loss: 0.0058 - val_ssim: 0.8947
# Epoch 82/100
# 252/252 [==============================] - ETA: 0s - loss: 6.8213e-04 - ssim: 0.9523
# Epoch 82: loss improved from 0.00069 to 0.00068, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 6.8213e-04 - ssim: 0.9523 - val_loss: 0.0054 - val_ssim: 0.8985
# Epoch 83/100
# 252/252 [==============================] - ETA: 0s - loss: 7.0572e-04 - ssim: 0.9513
# Epoch 83: loss did not improve from 0.00068
# 252/252 [==============================] - 35s 140ms/step - loss: 7.0572e-04 - ssim: 0.9513 - val_loss: 0.0051 - val_ssim: 0.8965
# Epoch 84/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6421e-04 - ssim: 0.9539
# Epoch 84: loss improved from 0.00068 to 0.00066, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 6.6421e-04 - ssim: 0.9539 - val_loss: 0.0062 - val_ssim: 0.8883
# Epoch 85/100
# 252/252 [==============================] - ETA: 0s - loss: 6.7253e-04 - ssim: 0.9529
# Epoch 85: loss did not improve from 0.00066
# 252/252 [==============================] - 35s 140ms/step - loss: 6.7253e-04 - ssim: 0.9529 - val_loss: 0.0050 - val_ssim: 0.8938
# Epoch 86/100
# 252/252 [==============================] - ETA: 0s - loss: 6.7204e-04 - ssim: 0.9535
# Epoch 86: loss did not improve from 0.00066
# 252/252 [==============================] - 35s 140ms/step - loss: 6.7204e-04 - ssim: 0.9535 - val_loss: 0.0053 - val_ssim: 0.8972
# Epoch 87/100
# 252/252 [==============================] - ETA: 0s - loss: 6.7770e-04 - ssim: 0.9534
# Epoch 87: loss did not improve from 0.00066
# 252/252 [==============================] - 35s 137ms/step - loss: 6.7770e-04 - ssim: 0.9534 - val_loss: 0.0055 - val_ssim: 0.8975
# Epoch 88/100
# 252/252 [==============================] - ETA: 0s - loss: 6.9322e-04 - ssim: 0.9527
# Epoch 88: loss did not improve from 0.00066
# 252/252 [==============================] - 34s 137ms/step - loss: 6.9322e-04 - ssim: 0.9527 - val_loss: 0.0055 - val_ssim: 0.8876
# Epoch 89/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6345e-04 - ssim: 0.9541
# Epoch 89: loss improved from 0.00066 to 0.00066, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 35s 139ms/step - loss: 6.6345e-04 - ssim: 0.9541 - val_loss: 0.0056 - val_ssim: 0.8842
# Epoch 90/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6864e-04 - ssim: 0.9545
# Epoch 90: loss did not improve from 0.00066
# 252/252 [==============================] - 35s 140ms/step - loss: 6.6864e-04 - ssim: 0.9545 - val_loss: 0.0056 - val_ssim: 0.8831
# Epoch 91/100
# 252/252 [==============================] - ETA: 0s - loss: 6.6890e-04 - ssim: 0.9543
# Epoch 91: loss did not improve from 0.00066
# 252/252 [==============================] - 35s 137ms/step - loss: 6.6890e-04 - ssim: 0.9543 - val_loss: 0.0049 - val_ssim: 0.9155
# Epoch 92/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5720e-04 - ssim: 0.9550
# Epoch 92: loss improved from 0.00066 to 0.00066, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 143ms/step - loss: 6.5720e-04 - ssim: 0.9550 - val_loss: 0.0059 - val_ssim: 0.9013
# Epoch 93/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4150e-04 - ssim: 0.9558
# Epoch 93: loss improved from 0.00066 to 0.00064, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 6.4150e-04 - ssim: 0.9558 - val_loss: 0.0063 - val_ssim: 0.8941
# Epoch 94/100
# 252/252 [==============================] - ETA: 0s - loss: 6.4161e-04 - ssim: 0.9562
# Epoch 94: loss did not improve from 0.00064
# 252/252 [==============================] - 35s 141ms/step - loss: 6.4161e-04 - ssim: 0.9562 - val_loss: 0.0059 - val_ssim: 0.9013
# Epoch 95/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5403e-04 - ssim: 0.9557
# Epoch 95: loss did not improve from 0.00064
# 252/252 [==============================] - 35s 140ms/step - loss: 6.5403e-04 - ssim: 0.9557 - val_loss: 0.0058 - val_ssim: 0.9079
# Epoch 96/100
# 252/252 [==============================] - ETA: 0s - loss: 6.5265e-04 - ssim: 0.9562
# Epoch 96: loss did not improve from 0.00064
# 252/252 [==============================] - 35s 138ms/step - loss: 6.5265e-04 - ssim: 0.9562 - val_loss: 0.0074 - val_ssim: 0.9018
# Epoch 97/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2493e-04 - ssim: 0.9586
# Epoch 97: loss improved from 0.00064 to 0.00062, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 6.2493e-04 - ssim: 0.9586 - val_loss: 0.0058 - val_ssim: 0.8933
# Epoch 98/100
# 252/252 [==============================] - ETA: 0s - loss: 6.3773e-04 - ssim: 0.9579
# Epoch 98: loss did not improve from 0.00062
# 252/252 [==============================] - 35s 141ms/step - loss: 6.3773e-04 - ssim: 0.9579 - val_loss: 0.0075 - val_ssim: 0.9000
# Epoch 99/100
# 252/252 [==============================] - ETA: 0s - loss: 6.2464e-04 - ssim: 0.9586
# Epoch 99: loss improved from 0.00062 to 0.00062, saving model to /kaggle/working/unet4.h5
# 252/252 [==============================] - 36s 142ms/step - loss: 6.2464e-04 - ssim: 0.9586 - val_loss: 0.0065 - val_ssim: 0.8993
# Epoch 100/100
# 252/252 [==============================] - ETA: 0s - loss: 6.3555e-04 - ssim: 0.9582
# Epoch 100: loss did not improve from 0.00062
# 252/252 [==============================] - 35s 140ms/step - loss: 6.3555e-04 - ssim: 0.9582 - val_loss: 0.0062 - val_ssim: 0.8934

# %%
import pickle
with open('/kaggle/working/history.pkl', 'wb') as f:
    pickle.dump(history.history, f)

# %%
print(type(history.history))
# Out:
# <class 'dict'>

# %%
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1)
  
dependencies = {
    'ssim': ssim
}

# %%
#model = keras.models.load_model('/kaggle/working/unet4.h5', custom_objects=dependencies)
model = keras.models.load_model('/kaggle/input/unetmodel1/4encoder_base512_model.h5', custom_objects=dependencies)

# %%
import pickle
with open('/kaggle/working/history.pkl', 'rb') as f:
    history = pickle.load(f)

# %%
import seaborn as sns
sns.set_style('dark')

# %%
plt.figure(figsize=(20,8))
loss = history['loss']
val_loss = history['val_loss']
length = len(loss)
plt.plot(history['loss'])
plt.plot(history['val_loss'])
#plt.xticks(range(16), range(5,21))

plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.figure(figsize=(20,8))
plt.plot(history['ssim'])
plt.plot(history['val_ssim'])
plt.title('SSIM')
plt.ylabel('ssim')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
random_val_samples = val_generator.__next__()
val_image_samples = random_val_samples[0]
val_mask_samples = random_val_samples[1]
predicted_masks = model.predict(val_image_samples)
# Out:
# 1/1 [==============================] - 0s 457ms/step

# %%
fig, axs = plt.subplots(1 , 3, figsize=(20,4))
axs[0].imshow(random_val_samples[0][0])
axs[0].set_title('Input Image')
axs[1].imshow(val_mask_samples[0])
axs[1].set_title('Actual Image')
axs[2].imshow(predicted_masks[0])
axs[2].set_title('Reconstructed Image')

print(predicted_masks[0].shape)
print(val_mask_samples[0].shape)
print(random_val_samples[0][0].shape)
#cv2.imwrite(op_path + '/train_img.jpg',t_image)
#cv2.imwrite(op_path + '/actual_img.jpg', a_image)
#cv2.imwrite(op_path + '/predicted.jpg', image)
# Out:
# (256, 256, 3)
# (256, 256, 3)
# (256, 256, 3)

# %%
# p_image = (predicted_masks[0] * 255).astype(np.uint8)
# a_image = (val_mask_samples[0] * 255).astype(np.uint8)
# t_image = (random_val_samples[0][0] * 255).astype(np.uint8)

# %%
# generate image dataset
img_dim = 256
batch_sz = 1
image_datagen = ImageDataGenerator(rescale=1./255)
mask_datagen = ImageDataGenerator(rescale=1./255)
#print(image_datagen.shape)

test_image_generator = image_datagen.flow_from_directory(
        test_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['vary_rings'],
        # color_mode=,
        batch_size = batch_sz,
        seed=42,
        subset='training')
    
test_mask_generator = mask_datagen.flow_from_directory(
        test_path,
        target_size=(img_dim, img_dim),
        class_mode = None,
        classes = ['true_images'],
        batch_size = batch_sz,
        seed=42,
        subset='training')

#image_datagen = ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
#mask_datagen = ImageDataGenerator(shear_range=0.5, rotation_range=50, zoom_range=0.2, width_shift_range=0.2, height_shift_range=0.2, fill_mode='reflect')
# train_generator = zip(train_image_generator, train_mask_generator)
# val_generator = zip(val_image_generator, val_mask_generator)
test_generator = zip(test_image_generator, test_mask_generator)
# Out:
# Found 303 images belonging to 1 classes.
# Found 303 images belonging to 1 classes.

# %%
Ssim = []
n = 0
for i,m in test_generator:
    if n<304:
        img,mask = i,m
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        #print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        Ssim.append(acc)
        n=n+1
    else:
        break
# Out:
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step

# %%
print(np.average(Ssim))
# Out:
# 0.9159452

# %%
fig, ax = plt.subplots()

# Create a boxplot
ax.boxplot(Ssim)

# Set axis labels and title
ax.set_xlabel('Data')
ax.set_ylabel('Values')
ax.set_title('Boxplot of Data')

# Show the plot
plt.show()

# %%
Ssim = []
n = 0
for i,m in test_generator:
    img,mask = i,m
    if n<5:
        pred = model.predict(i)
        acc = ssim(mask[0], pred[0])
        print('SSIM: {}'.format(ssim(mask[0], pred[0])))
        image1_array = mask[0]  # Get the NumPy array directly from the mask
        image2_array = pred[0]
        
        #image1_gray = mask[0].convert("L")
        #image2_gray = pred[0].convert("L")

# Convert the images to numpy arrays
        #image1_array = np.array(image1_gray)
        #image2_array = np.array(image2_gray)

# Compute the absolute difference between the two images
        diff_array = np.abs(image1_array - image2_array)
        #diff_array[0][3] = 1

# Find the maximum and minimum values in the difference matrix
        max_value = np.max(diff_array)
        min_value = np.min(diff_array)
        print(max_value)
        print(min_value)
        #max_value = 1
        fig, axes = plt.subplots(1, 3, figsize=(12, 4))
        axes[0].imshow(mask[0])
        axes[0].set_title("Actual")
        axes[1].imshow(pred[0])
        axes[1].set_title("Predicted")
        im = axes[2].imshow(diff_array, cmap="gray", vmax=max_value, vmin=min_value)
        axes[2].set_title("Difference")
        plt.colorbar(im, ax=axes[2])

        # Display the plot
        plt.show()
        n+=1
    else:
        break
# Out:
# 1/1 [==============================] - 7s 7s/step
# SSIM: 0.892162561416626
# 0.4666667
# 2.3841858e-07
# 1/1 [==============================] - 0s 26ms/step
# SSIM: 0.8924285769462585
# 0.454902
# 1.4901161e-07
# 1/1 [==============================] - 0s 23ms/step
# SSIM: 0.8915948867797852
# 0.454902
# 5.9604645e-07
# 1/1 [==============================] - 0s 22ms/step
# SSIM: 0.8916525840759277
# 0.46274513
# 3.5762787e-07
# 1/1 [==============================] - 0s 23ms/step
# SSIM: 0.9637730717658997
# 0.16722953
# 7.1525574e-07
